# %%
confs = []
confs.append("""
📌 1. Présentation d’Orange et du pôle NLP
Orange = grand groupe (~140k employés), 62% en France.
Orange Innovation : regroupe chercheurs, devs, designers, data scientists.
Organisation en pôles :
Réseau (cœur d’Orange)
Services
Data et IA (pôle plus récent, rassemblement des expertises IA)
Domaines de recherche en IA chez Orange :
Network & infrastructures
Trust, Security & Transactions
Augmented Operations
Augmented Customers & Collaborators (Géraldine travaille ici)
Solutions for Sustainable Economy

🏢 2. Organisation de son équipe (Deskin, Lannion)
22 personnes : chercheurs, devs, data scientists, PhD, alternants.
Travail entre recherche et delivery (collaboration et support aux équipes internes).
NEPAL research program (NLP and Application).

🧠 3. Domaines d'application du NLP chez Orange
Adaptation de modèles de langage aux besoins métiers :
Relation client
Gestion documentaire / knowledge management
Interaction homme-machine : Chatbots, Voicebots
Pas seulement de l’IA générative :
Extraction de mots-clés
Vérification et structuration de l’information

🔬 4. Recherche NLP : Méthodologies et Projets
📍 Grands projets en cours
Tâches complexes et approche agent-based :
Décomposition en sous-tâches.
Impact sur les interactions avec des assistants virtuels.
Évaluation = sujet de recherche important.
Approches sémantiques avancées :
Abstract Meaning Representation (AMR) : Graphes de sens inspirés de PropBank.
FrameNet : Modèle basé sur des frames (encodage BIO).
Génération automatique de graphes AMR via modèles LLM.
🏗️ Méthodologie générale du NLP
Définir une tâche NLP
Comprendre le besoin métier (les clients internes ne savent souvent pas ce qu'ils veulent)
Rédiger un guide d’annotation
Collecter et annoter des données (avec plusieurs annotateurs si possible)
Construire un système de NLP
Évaluer les performances (souvent inventer une métrique spécifique)

⚙️ 5. Expérimentations avec des modèles IA
Comparaison des perfs sur différentes tâches NLP :
BERT (0.66)
Phi-3 (0.22, mais mieux après fine-tuning)
GPT-4o mini (0.80)
Fine-tuning de Phi-3 → Résultats proches de GPT-4o mini.
Impact carbone du fine-tuning 📉⚡ :
Coût énergétique élevé.
Manque de transparence sur les émissions des modèles propriétaires (OpenAI notamment).

🔍 6. Retrieval-Augmented Generation (RAG) et Agents
RAG : Utilisé pour interroger des documents avec un LLM.


Indexation des documents.
Découpe en petits blocs pour optimiser la récupération informations.
Limite : fonctionne mal pour les questions sur la structure d’un document.
GraphRAG : améliore le RAG en structurant mieux les connaissances.


Mieux adapté aux concepts complexes et relations sémantiques.
Agents : Systèmes autonomes capables d'utiliser des outils (calculs Python, recherche documentaire...).


Plus flexibles et polyvalents.
Comparaison avec Copilot.
Meilleur compromis entre recherche informations et prise de décision.

⚖️ 7. Régulation et cadre légal
IA Act (UE) : tentative de réguler les usages de l’IA en entreprise.
Orange a testé 8 modèles (RAG, GraphRAG, Agents...).
Évaluation par LLMs (trop coûteux en évaluation humaine).

💡 8. Observations sur l’usage des IA génératives chez Orange
Évolution des usages :
Moins de questions généralistes.
Plus de reformulations, génération de code.
4 taxonomies pour analyser les prompts :
Tâche
Domaine
Formulation du prompt (NL, code, structuré)
Type de réponse attendue
Annotation avec des prompts : exploration du fine-tuning plutôt que l’évaluation circulaire.

💬 Conclusion :
 La conférence de Géraldine Damnati donne un bon aperçu du travail NLP chez Orange. Son équipe travaille sur des applications concrètes en entreprise, tout en menant des recherches avancées sur l’IA et la sémantique. Orange explore plusieurs approches comme RAG, GraphRAG et Agents, et suit de près la réglementation sur l’IA. 🚀
""")

confs.append("""
🎓 1. Parcours académique
Licence en Sciences du Langage (Orléans) :

Spécialisation en TAL dès la L2.
Master en Linguistique appliquée aux STIC (moins informatique que le Master TAL).
Annotation sur ESLO (corpus oral d’Orléans).
Stages :


Laboratoire Ligérien de Linguistique (Orléans)


Constitution et exploitation de corpus oraux (ESLO, LudoCorp).
Travail sur langues peu dotées et outils d’annotation.
BRGM (Bureau des Recherches Géologiques et Minières)


Conception d’un tableau de bord pour le suivi des demandes.
Travail en traitement de données (XML, PHP, HTML, JS, CSS, Google Charts).
Orange Labs (Lannion)


Analyse sémantique / NER / Web sémantique & Linked Open Data (RDF).
Récupération et analyse de pages Wikipédia contenant des entités nommées (ex : variations de "Paris").
Doctorat :


Annotation des lieux (massive lexicale sur ESLO).
Étude de la perception des villes via analyse des transcriptions ESLO.
Modèle d’identification des lieux et projection sur carte interactive.

🚆 2. Rôle et missions à la SNCF
SNCF = Groupe divisé en plusieurs filiales.
Direction Technologies & Innovations → Direction de la Recherche → Direction des Matériaux.
Entrée en 2020 comme cheffe de projet TAL (passage à l’IA générative en 2022).
Missions principales
Pilotage de projets TAL & IA :


Définition des briques technologiques.
Identification des besoins métiers (terrain et bureaux).
Mise en relation avec les partenaires techniques.
Apport d’expertise TAL :


Gestion de bases documentaires.
Recherche informations dans des corpus internes.
Démystification de l’IA et formation aux usages concrets.
SNCF et l’IA :


60 doctorants en interne.
22 brevets déposés en 2022 sur des sujets variés.
Un plateau IA regroupant plusieurs domaines :
Vision artificielle.
Prédiction de séries temporelles.
TAL.
Prédiction des retards / détection d’anomalies.
Relation client intelligente.
Aide à la conduite.
Problématiques RGPD.

📊 3. Projets & applications en TAL
Gestion des référentiels documentaires
Extraction et structuration des données.
Parsing de documents.
Suivi de mise à jour de contenus.
Identification informations contradictoires.
Acculturation IA (vulgarisation en interne)
Explication des concepts :
IA, IA générative, Machine Learning, Deep Learning, LLM.
Présentation des cas d’usage concrets.
RAG & NLP avancé
Projet DSMAT :
Utilisation du RAG (Retrieval-Augmented Generation) pour interroger une base documentaire vectorisée.
IAMADOC = système de recherche informations interne.
Nouvelles perspectives IA
Estimation des flux de personnes via caméras & détection de personnes.
Reconnaissance de pièces pour inventaire.

💡 Conclusion
Hélène Flamein a un parcours hybride entre linguistique, TAL et ingénierie. Son travail à la SNCF montre comment le traitement automatique du langage s’intègre dans un grand groupe industriel, avec des cas d’usage métiers concrets :
 📌 Recherche informations, gestion documentaire, prédiction ferroviaire, analyse sémantique, et RAG pour améliorer les bases de données internes. 🚆
""")

confs.append("""
www.thalesgroup.com
Le NLP à Thales /
cortAIX Labs
Bénédicte Goujon,
ingénieure de recherche
2
Thales Research & Technology France trtp version 9.0.0 selon modèle
Plan
Présentation de l’entreprise
 Du groupe Thales au laboratoire de recherche avec NLP
TAL & NLP à Thales R&T / CortAIx Labs
 Activité principale : extraction d’informations textuelles spécifiques
 Phase 1 (2000 – 2011)
 Phase 2 (2018 - …)
– L’outil STRASS
– Les Transformers et l’évaluation
– La construction d’un corpus d’apprentissage
3
Thales Research & Technology France trtp version 9.0.0 selon modèle
Légende des couleurs
Synthèse sur les technos d’extraction d’informations
Bénédicte Goujon, Extraction d’informations spécifiques à partir de textes avec peu de textes
d’apprentissage, TextMine 2021.
Bénédicte Goujon, Élaboration d’un corpus d’apprentissage à partir d’articles de recherche en
chimie, ARTS (TALN) 2023.
4
Thales Research & Technology France trtp version 9.0.0 selon modèle
L’entreprise : le groupe Thales (chiffres clés 2023)
3 secteurs d’activité
81 000 employés
68 pays
1,1 Milliard € investis dans la
R&D autofinancée
5
Thales Research & Technology France trtp version 9.0.0 selon modèle
La mission du groupe Thales
Détection &
collecte des
données
Transmission &
stockage de
données
Traitement des
données & prise
de décision
Chaîne de décision critique
PERMETTRE À NOS CLIENTS
D’ABORDER AVEC CONFIANCE
LEURS MOMENTS DÉCISIFS
6
Thales Research & Technology France trtp version 9.0.0 selon modèle
Thales Research & Technology : les centres de recherche du groupe
(2024)
A worldwide network
5 TRT
France, UK,
Netherlands, Canada,
Singapore
400 R&T
staff
50 PhD
students
20% of
Group
R&T
activity
7 joint
labs
Excellence
 External recognition
 Senior experts
Partnerships
 Embedded at the heart of innovation ecosystems
 Joint laboratories
High visibility
 Strongly present within national & European R&D
networks
7
Thales Research & Technology France trtp version 9.0.0 selon modèle
Thales Research & Technology France, Plateau de Saclay (2024)
Key Figures
 TRT permanent research staff : 250
 35+ PhDs
 50 invention disclosures, 35 patents / year
 50+ scientific publications / year
 Clean rooms : 4 000 m²
 1 Nobel Prize (Albert Fert), 3 European Research Council projects (ERC)
 80 French or European on-going collaborative research projects
Julie Grollier (CNRS)
Prize Irène Joliot-Curie 2021
Category :
« Scientific woman of the year »
8
Thales Research & Technology France trtp version 9.0.0 selon modèle
Thales Research & Technology France (2024)
Physique TRT
Technologie et
Mesures
Sciences et
Techniques de
l’Information
LCHP : Laboratoire Calcul
Hautes Performances
LDO : Laboratoire aide à la
Décision et Optimisation
LISL : Laboratoire Ingénierie
Système Logiciel
LSEC : Laboratoire Systèmes
Embarqués Critiques
LRASC : Laboratoire
Raisonnement et Analyse
dans les Systèmes Complexes
9
Thales Research & Technology France trtp version 9.0.0 selon modèle
cortAIx Labs (2025)
CortAIx
/ Labs
Sciences et
Techniques de
l’Information
THERESIS
DIGITAL FACTORY
10 Thales Research & Technology France trtp version 9.0.0 selon modèle
ARX (ancien nom : LRASC), 18 personnes
Sense-Making
Situation Awareness
Validity
Intelligibility
Efficiency
Algorithm
Validation
KnowledgeGraph Mining
& Reasoning
Hybrid
Inference
Models
End-to-End Trustable AI
Extraction d’informations
Fusion
Ontologies NLP
11 Thales Research & Technology France trtp version 9.0.0 selon modèle
Thème : « Knowledge-Graph Mining & Reasoning »
Questions ?
12 Thales Research & Technology France trtp version 9.0.0 selon modèle
Plan
Présentation de l’entreprise
 Du groupe Thales au laboratoire de recherche avec NLP
TAL & NLP à Thales R&T / CortAIx Labs
 Activité principale : extraction d’informations textuelles spécifiques
 Phase 1 (2000 – 2011)
 Phase 2 (2018 - …)
– L’outil STRASS
– Les Transformers et l’évaluation
– La construction d’un corpus d’apprentissage
13 Thales Research & Technology France trtp version 9.0.0 selon modèle
Mon parcours avant Thales et hors NLP dans Thales
Parcours universitaire
 Maîtrise (master 1) MASS : mathématiques, informatique et économie.
 DEA (master 2 orienté recherche) en traitement automatique du langage naturel.
 Thèse en contrat CIFRE (en entreprise), soutenue en 2000, sur l’extraction d’informations textuelles à partir de
brevets pour la veille.
Activités sur l’aide à la décision
 Apprentissage de préférences
 Intégrale de Choquet 2-additive
 Placement de capteurs à l’aide d’algos évolutionnaires
14 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T : extraction d’informations spécifiques
Types d’approche Connaissances en
entrée
Avantages Limites
Symbolique
Règles, patrons
linguistiques écrits
manuellement +
dictionnaires
- Explication assez
simple des résultats
- Bonne qualité des
résultats
- Coût élevé de la construction des
connaissances (besoin d’expertise
linguistique)
- Difficulté à couvrir tous les cas
Contexte 1 (2000 – 2011)
Une tentative de coup d'État à Abidjan dégénère en soulèvement armé.
Plusieurs centaines de victimes à Abidjan et à Bouaké. Laurent Gbagbo est
à Rome. Le général Gueï et le ministre de l'Intérieur du gouvernement
Gbagbo, Émile Boga Doudou sont tués. Les villes de Bouaké et Korhogo,
respectivement dans le centre et le nord du pays, tombent entre les mains de
rebelles.
Exemple de texte annoté (entités)
Exemple de patron linguistique (Unitex)
15 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T : extraction d’informations spécifiques
Types d’approche Connaissances en
entrée
Avantages Limites
Symbolique
Règles, patrons
linguistiques écrits
manuellement +
dictionnaires
- Explication assez
simple des résultats
- Bonne qualité des
résultats
- Coût élevé de la construction des
connaissances (besoin d’expertise
linguistique)
- Difficulté à couvrir tous les cas
Statistique
Corpus annotés
volumineux
- Assez faible
complexité pour
annoter des
documents pour
l’apprentissage
- Difficulté à produire des corpus
annotés volumineux en entrée.
- Difficulté à expliquer les résultats.
- Qualité aléatoire des résultats
16 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T – Phase 1
Financement de la recherche : projets internes et projets externes
Exemple de projet interne Thales
 Projet TVS : plateforme de commandes vocales (2000-2004)
 Application initiale: logiciel d’entraînement au commandement de troupes.
 Mon travail : écritures de grammaires génériques et de lexiques spécifiques pour la reconnaissance vocale
pour générer une grammaire spécifique couvrant le maximum de cas.
 Dépôt d’un brevet : « PROCEDE D'ELABORATION D'UNE GRAMMAIRE SPECIFIQUE A UN DOMAINE A PARTIR
D'UNE GRAMMAIRE SOUS-SPECIFIEE »
17 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T – Phase 1
Exemple de projet externe :
 Projet Outilex : plateforme pour l’analyse textuelle (ANR RNTL, 2004-2006)
 But du projet : réalisation d’une plateforme style Unitex, avec gestion du XML, dictionnaires multilingues
(UMLV, Systran, CEA, Lingway, ... )
 Participation de TRT : réalisation d’un système de filtrage thématique de documents audio au niveau
phonétique
18 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T – Phase 1
Annotation automatique de l’incertain dans des textes (2007 - 2010)
 Objectif : dans un contexte d’extraction automatique d’événements à partir de textes, on veut capter les
nuances exprimées.
1. « Laurent Gbagbo devrait se rendre en Italie. »
2. « Laurent Gbagbo ne se rendra sûrement pas la semaine prochaine en Italie. »
3. « Laurent Gbagbo ne s’est pas rendu en Italie. »
4. « Selon le leader des rebelles, Laurent Gbagbo s’est rendu hier en Italie. »
5. « Selon son porte-parole, Laurent Gbagbo s’est rendu hier en Italie. »
19 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T – Phase 1
Annotation automatique de l’incertain dans des textes (2007 - 2010)
 Objectif : dans un contexte d’extraction automatique d’événements à partir de textes, on veut capter les
nuances exprimées.
1. « Laurent Gbagbo devrait se rendre en Italie. »
2. « Laurent Gbagbo ne se rendra sûrement pas la semaine prochaine en Italie. »
3. « Laurent Gbagbo ne s’est pas rendu en Italie. »
4. « Selon le leader des rebelles, Laurent Gbagbo s’est rendu hier en Italie. »
5. « Selon son porte-parole, Laurent Gbagbo s’est rendu hier en Italie. »
 Caractéristiques et valeurs en lien avec l’expression de l’incertain :
– Temps de l’événement décrit dans le texte : passé, futur, présent.
– Incertitude : certitude, incertitude faible, incertitude moyenne, incertitude forte.
– Polarité : affirmatif, négatif.
– Source de l’information spécifiée dans le texte : valeur à extraire du texte
20 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T – Phase 1
Annotation automatique de l’incertain dans des textes (2007 – 2010)
 Objectif : dans un contexte d’extraction automatique d’événements à partir de textes, on veut capter les
nuances exprimées.
1. « Laurent Gbagbo devrait se rendre en Italie. » => Temps : futur, Incertitude : incertitude moyenne.
2. « Laurent Gbagbo ne se rendra sûrement pas la semaine prochaine en Italie. » => Temps : futur, Incertitude :
incertitude faible.
3. « Laurent Gbagbo ne s’est pas rendu en Italie. » => Temps : passé, Polarité : négation.
4. « Selon le leader des rebelles, Laurent Gbagbo s’est rendu hier en Italie. » => Temps : passé, Incertitude :
incertitude moyenne, source : le leader des rebelles.
5. « Selon son porte-parole, Laurent Gbagbo s’est rendu hier en Italie. » => Temps : passé, Incertitude : incertitude
moyenne, source : son porte-parole.
 Problématique complémentaire : intégrer la fiabilité d’une source.
21 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T – Phase 1
Tool: SemPlus (java, 2005 – 2011)
 Objectives : production of structured information from unstructured texts + autonomy of users without any
linguistic skills
 Specific target: extraction of binary relations between entities (use of existing named entity dictionaries)
Learning algorithm for relation pattern acquisition (“contact”)
1. Manual capture of couples checking a pertinent relation; “Jacques Chirac” / “Laurent Gbagbo”
2. Automatic retrieval of sentences containing those couples, so with potential patterns expressing the relation;
“Jacques Chirac had phoned on Wednesday to Laurent Gbagbo”
3. Manual capture of extracts expressing the relations in those sentences and automatic generation of
corresponding patterns;
“Jacques Chirac had phoned ** to Laurent Gbagbo” Subject: Jacques Chirac, Relation: Contact, Complement:
Laurent Gbagbo
<Person>1 <to phone> ** to <Person>2 = Contact(<Person>1
, <Person>2
)
4. Automatic application of patterns : retrieval of novel couples => 2.
“Jacques Chirac had phoned on the 17th of July to Vojislav Kostunica” => “Jacques Chirac” / “Vojislav
Kostunica”
23 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T – Phase 1
SemPlus
 Extraction de relations binaires entre entités nommées => vise généralement les relations statiques entre
instances uniques :
– « L’A380 d’Airbus » =>
– « Des cations tels que le sodium, le potassium, … » =>
– « Barack Obama est le président des USA » =>
 Utilisation de l’extraction de relations
– Acquisition de connaissances (propriétés d’ontologies)
– Extraction d’informations pour d’autres modules (exemple : fusion).
– Recherche d’informations précises : Personne – président de – Société
 Méthodes les plus courantes à la fin des années 2000
– Graphes, patrons linguistiques
– Statistiques, probabilités (Personne prox président prox Organisation => relation)
Arrêt des travaux sur le TAL à TRT en 2010
 Transfert de l’expertise acquise avec SemPlus vers la start-up Arisem (1994 – 2011) du groupe Thales.
A380 construit par Airbus
Barack Obama président de USA
cation a comme instance sodium
24 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T : extraction d’informations spécifiques
Types d’approche,
outil
Connaissances en
entrée
Avantages Limites
Symbolique
Règles, patrons
linguistiques écrits
manuellement +
dictionnaires
- Explication assez simple
des résultats
- Bonne qualité des
résultats
- Coût élevé de la construction des
connaissances (besoin
d’expertise linguistique)
- Difficulté à couvrir tous les cas
Statistique
Corpus annotés
volumineux
- Assez faible complexité
pour annoter des
documents pour
l’apprentissage
- Difficulté à produire des corpus
annotés volumineux en entrée.
- Difficulté à expliquer les résultats.
- Qualité aléatoire des résultats
SemPlus : approche
symbolique
améliorée
Exemples +
dictionnaire d’entités
=> patrons
linguistiques
- Assez faible complexité
pour annoter des
documents pour
l’apprentissage
- Explication assez simple
des résultats
- Difficulté à couvrir tous les cas
Contexte 1 (2000 – 2011)
Questions ?
25 Thales Research & Technology France trtp version 9.0.0 selon modèle
Plan
Présentation de l’entreprise
 Du groupe Thales au laboratoire de recherche avec NLP
TAL & NLP à Thales R&T / CortAIx Labs
 Activité principale : extraction d’informations textuelles spécifiques
 Phase 1 (2000 – 2011)
 Phase 2 (2018 - …)
– L’outil STRASS
– Les Transformers et l’évaluation
– La construction d’un corpus d’apprentissage
26 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T – Phase 2
Redémarrage des travaux sur le TAL à TRT en 2018
 Premier besoin en extraction d’informations à partir de tickets décrivant des problèmes de connexion à
internet avec détails sur les références des modems, du type de connexion (wifi ou filaire)…
Nouveau prototype : STRASS (2020 – …)
 Vise l’extraction de relations entre entités
 En Python. Utilisation de la librairie spaCy pour les pré-traitements génériques (découpage en phrases,
tokenisation…)
27 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T – Phase 2
Présentation de STRASS
 Slides suivants tirés de la présentation à TextMine 2021 : « Extraction d’informations spécifiques à partir de
textes avec peu de textes d’apprentissage »
28 Thales Research & Technology France trtp version 9.0.0 selon modèle
Problématique
Contexte
 Nombreux besoins de clients liés à l’extraction d’informations à partir de textes
– Extraction de concepts spécifiques à des domaines, de relations entre concepts…
– Principalement en anglais.
 Solutions du marché
– Succès actuel du machine learning, avec des outils de détection d’entités nommées génériques.
– Exemple : spaCy : détection de 18 types d’entités nommées (PERSON, ORG, DATE…),15 langues.
 Limites
– Les clients demandent du machine learning mais ne disposent pas de gros corpus annotés.
– Les entités nommées génériques sont insuffisantes.
La plateforme STRASS
 Outil d’aide à l’acquisition de connaissances linguistiques pour une annotation en lien avec les
besoins du client, avec peu de textes d’apprentissage.
29 Thales Research & Technology France trtp version 9.0.0 selon modèle
L’extraction d’informations : besoins spécifiques
Besoins en extraction d’informations
 Entités et événements spécifiques, ex : WEAPON, MATERIAL, PROBLEM, MURDER…
 Relations entre entités, ex : Affiliation, Possession, ProductOf…
 Arguments reliant des événements et des entités, ex : mean (entre MURDER et WEAPON), victim
(entre MURDER et PERSON), attacker (entre MURDER et PERSON)…
30 Thales Research & Technology France trtp version 9.0.0 selon modèle
L’extraction d’informations : besoins spécifiques, état de l’art
Solutions, état de l’art
 Construction manuelle d’un corpus annoté volumineux (outils BRAT, WebAnno, prodigy…) pour
utiliser des approches de machine learning (ex: spaCy, NLTK, OpenNLP, coreNLP)
– Limites: assez coûteux en main d’œuvre ; nécessite une ontologie et une méthodologie d’annotation
précises.
 Appel à des linguistes pour la construction de patrons d’extraction spécifiques (en interne avec
Gate ou Unitex, en externe) => coûteux en main d’œuvre qualifiée.
 Apprentissage de patrons linguistiques, à partir de corpus annotés réduits : dès 1993 avec AutoSlog,
de 2004 à 2010, SemPlus à Thales R&T => approche dans STRASS.
 Expansion de données d’apprentissage : Liao et Grishman (2011), Wang et al (2019).
31 Thales Research & Technology France trtp version 9.0.0 selon modèle
La plateforme STRASS
WebAnno
Ontologie
du domaine
(entités,
événements,
relations) Annotation
manuelle Textes
annotés
Nouveaux
textes
STRASS
annotation
automatique
Nouveaux
textes
annotés
Phase d’apprentissage
Phase d’annotation
Modèle
d’annotation
(avec patrons
linguistiques de
relations et
dictionnaires)
Modèle
d’annotation
STRASS
apprentissage du
modèle d’annotation
(entités, événements,
relations)
Corpus
Analyses génériques : spaCy
Analyses spécifiques : code STRASS (python)
32 Thales Research & Technology France trtp version 9.0.0 selon modèle
Exemple d’utilisation de STRASS
Corpus « Predicting Terrorism » (1)
 Plus de 29 000 textes courts décrivant le bilan d’attaques terroristes.
Besoin imaginé
 Détection du nombre de morts, du nombre de blessés, du lieu, des agresseurs, des armes
utilisées…
Modèle
 Entités
– PERSON, LOC, NORP, CARDINAL, WEAPON…
 Evénements
– Murder, Injure, Attack, Die.
 Relations
– Entre entités : Affiliation, How-Many.
– Arguments : deadVictim, injuredVictim, attacker, mean, where, when.
Nationalities Or Religious or Political groups
(1) https://www.kaggle.com/argolof/predicting-terrorism
33 Thales Research & Technology France trtp version 9.0.0 selon modèle
Exemple d’utilisation de la plateforme STRASS
Ontologie :
19 entités,
4 événements,
2 relations,
6 arguments Annotation
manuelle Textes
annotés
"One Iraqi policeman was killed
,and at least ten bystanders were
injured when a car bomb
exploded outside a police station".
STRASS
annotation
automatique
Phase d’apprentissage
Phase d’annotation
Modèle d’annotation :
5 patrons prédéfinis (when, How-Many…)
3 patrons de relations,
21 patrons d’arguments,
40 entrées de dictionnaires.
Modèle
d’annotation
STRASS
apprentissage du
modèle d’annotation
Corpus :
11 textes
Principe des patrons: si {conditions} => ajout d’une relation
- Si PERSON est sujet passif de Murder => deadVictim
WebAnno
34 Thales Research & Technology France trtp version 9.0.0 selon modèle
Exemple d’utilisation de la plateforme STRASS
Apprentissage sur 11 textes annotés manuellement
(13 phrases).
 Five guards are injured in an Islamist attack on the airport.
 A doctor is gunned down by Sunnis on motorcycles, who also injure a patient.
 Islamic fundamentalists thought to be behind a bombing at a hospital that
injures eleven.
Exemple : annotation de 300 textes.
 2 871 annotations produites
 Dont 1 351 relations et arguments.
Type Nombre
d’instances
Entités
PERSON 622
CARDINAL 461
NORP 273
WEAPON 74
Evénements
Murder 214
Injure 146
Die 19
Attack 18
Relations
entre entités
How-Many 383
Affiliation 147
Arguments
deadVictim 208
injuredVictim 84
attacker 78
mean 41
35 Thales Research & Technology France trtp version 9.0.0 selon modèle
Perspectives
Plateforme STRASS en cours de développement
Evaluation qualitative souhaitée mais difficile à mettre en œuvre.
 Tenir compte de la spécificité de chaque concept, de la variabilité des expressions possibles… et
en tirer des explications sur d’éventuelles limites.
Intégration de la plateforme STRASS à la plateforme INCEpTION.
 INCEpTION : annotation manuelle (WebAnno), gestion d’ontologie, suggestion d’annotations lors
de l’annotation manuelle.
Etude des méthodes d’expansion des données d’apprentissage.
Questions ?
36 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T – Phase 2
Problématiques de modélisation des connaissances et d’annotation manuelle des textes
 Exemple sur un corpus décrivant des attaques terroristes :
 “One Iraqi policeman was killed”
 “A doctor is gunned down by Sunnis”
 “One of the dead was an 11-year old boy.”
 “A sectarian attack … leaves two people dead and two injured.”
 “Taliban elements ambush …, leaving two dead and two injured.”
 Quelques remarques sur les catégories possibles pour la modélisation et la mise en relation des concepts :
– Concepts : Person, Weapon, Event, Date, Location. Autres : State ?
– Problèmes sur la dernière phrase : pas de mention d’entité de type Person pour les relations !
– Difficulté : Gun_down contient à la fois l’événement, le moyen et l’état de la victime.
– Contrainte d’un nombre limité de catégories pour l’annotation manuelle, sinon perte en qualité.
– Post-traitements possibles : kill –target-> policeman => policeman –has_state-> dead
37 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T : extraction d’informations spécifiques
Contexte 2 (2018 – …)
Types d’approche Connaissances en
entrée
Avantages Limites
Symbolique
Règles, patrons
linguistiques écrits
manuellement +
dictionnaire
- Explication assez simple
des résultats
- Bonne qualité des résultats
- Coût élevé de la construction des
connaissances (besoin
d’expertise linguistique)
- Difficulté à couvrir tous les cas
Statistique
Corpus volumineux
annotés
- Assez faible complexité
pour annoter des documents
pour l’apprentissage
- Difficulté à produire des corpus
annotés volumineux en entrée.
- Difficulté à expliquer les résultats.
- Qualité aléatoire des résultats
STRASS : approche
hybride symbolique +
statistique (spaCy)
Patrons linguistiques
appris à partir
d’exemples
- Assez faible complexité
pour fournir les exemples
- Explication assez simple
des résultats
- Difficulté à couvrir tous les cas
38 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T – Phase 2
Etude des Transformers
 Transformers : réseaux de neurones avec attention
 Stage en 2022 sur l’évaluation des Transformers pour l’extraction automatique de relations entre entités.
– Pas de modèle existant pour l’extraction de relations via HuggingFace, mais exemple de code avec spaCy 3
– Types des entités et des relations spécifiques aux besoins Thales
– Peu de données d’apprentissage
Source: https://arxiv.org/abs/1706.03762
39 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T : extraction d’informations spécifiques
Contexte 2 (2018 – …)
Types d’approche Connaissances
en entrée
Avantages Limites
Symbolique
Règles, patrons
linguistiques écrits
manuellement +
dictionnaire
- Explication assez simple des
résultats
- Bonne qualité des résultats
- Coût élevé de la construction
des connaissances (besoin
d’expertise linguistique)
- Difficulté à couvrir tous les cas
Statistique
Corpus annotés
volumineux
- Assez faible complexité pour
annoter des documents pour
l’apprentissage
- Difficulté à produire des corpus
annotés volumineux en entrée.
- Difficulté à expliquer les résultats.
- Qualité aléatoire des résultats
STRASS : approche
hybride symbolique +
statistique (spaCy)
Patrons
linguistiques appris
à partir
d’exemples
- Assez faible complexité pour
fournir les exemples
- Explication assez simple des
résultats
- Difficulté à couvrir tous les cas
Transformers
Modèles existants
génériques +
corpus annotés
- Assez faible complexité pour
annoter des documents pour
l’apprentissage
- Adaptable avec des corpus
peu volumineux
- Prédictions
- Difficulté à expliquer les résultats.
40 Thales Research & Technology France trtp version 9.0.0 selon modèle
Sujet en cours (2023-2025) :
Evaluation des outils (STRASS, Transformers)
 Travail en cours sur l’évaluation des outils dans des contextes avec peu de données
d’apprentissage, où la mesure F1 n’est pas adaptée
 Besoin : caractérisation précise des contextes et outils pour une meilleur compréhension des
résultats obtenus avec des outils standards sur des données métiers
Caractérisation des étapes pour l’obtention de données annotées sur des domaines métiers
 Présentation faite lors de l’atelier ARTS (TALN) : Élaboration d’un corpus d’apprentissage à partir
d’articles de recherche en chimie
TAL & NLP à Thales R&T – Phase 2
41 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T – Phase 2
Evaluation des outils (STRASS, Transformers)
 Travail en cours sur l’évaluation des outils dans des contextes avec peu
de données d’apprentissage
Tâche : NER ==>
Source: Marco Naguib, LISN (INRIA, CNRS, UNIV PARIS SACLAY), 21/03/2024
42 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T – Phase 2
Evaluation des outils (STRASS, Transformers)
 Etude du corpus TACRED (Stanford), qui contient des annotations de 41 relations (+ no_relation).
 106 264 exemples en anglais.
 21,5% des relations ont des types précis.
 Distribution des relations :
Stanford TACRED Homepage:
https://nlp.stanford.edu/projects/tacred/
43 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T – Phase 2
Evaluation des outils (STRASS, Transformers)
 Travail en cours sur l’évaluation des outils dans des contextes avec peu
de données d’apprentissage
– La mesure F1 n’est pas suffisante
Relation Extraction with Fine-Tuned Large Language Models in Retrieval Augmented Generation Frameworks (arxiv.org) (2024)
44 Thales Research & Technology France trtp version 9.0.0 selon modèle
TAL & NLP à Thales R&T – Phase 2
Evaluation des outils (STRASS, Transformers)
 Prise en compte du contexte :
– Taille des corpus d’apprentissage
– Nombre de relations par phrase : 1, 10…
– Nombre d’entités dans une phrase : 2, 10…
– Forme des entités : uniquement noms propres, noms, verbes
– Référent des entités : unique, dépendant de la phrase
– Complexité des phrases
– Distance syntaxique entre entités en relation
– Types en relation
– …
Questions ?
45 Thales Research & Technology France trtp version 9.0.0 selon modèle
Une conclusion
Mon expérience en TAL & NLP à TRT-France (18 ans)
 8 projets collaboratifs financés (+ 3 en aide à la décision)
 8 projets internes pour des entités du groupe Thales (+ 3)
 4 brevets (+ 2)
 18 articles de recherche (+ 4 pendant ma thèse) (+ 8) (+ 10 revues de conférences)
 2 outils : SemPlus et STRASS
 Évolution : des approches symboliques vers des approches hybride avec LLM.
 Coordination/rédaction d’un rapport interne sur le NLP dans le groupe Thales, avec 17
contributions (2020)
 Encadrement de 6 stagiaires (master 2) et une doctorante (résolution de coréférences).
 Plusieurs interventions en masters 2.
Autant de problématiques de
modélisation des connaissances
visées et d’annotation de textes
46 Thales Research & Technology France trtp version 9.0.0 selon modèle
Une conclusion – suite
ChatGPT
 L’arrivée de ChatGPT a fortement modifié la visibilité du NLP
 Certain.es ont pensé que ChatGPT règlerait tous les problèmes de NLP :
plus besoin de faire du NLP, ChatGPT comprend tout !
 ChatGPT : basé initialement sur le LLM GPT-3 combiné à l’expertise
humaine (40 annotateur.ices) et le RL (reinforcement learning)
 Points forts : outil pouvant servir en support pour différentes tâches
plus ou moins pénibles :
– Génération de code
– Génération de textes bien formés pour expliquer des activités…
 Points faibles :
– Pas de connaissances validées et structurées internes à l’outil : ChatGPT peut affirmer des contre vérités.
– Biais liés aux données d’apprentissage.
 Dans Thales : pas mal de personnes utilisent ChatGPT pour différents besoins (rédaction, recherche
d’informations…). Certaines voient surtout ses forces, d’autres ses points faibles.
Nb of LLM parameters
47 Thales Research & Technology France trtp version 9.0.0 selon modèle
Les outils de NLP en 2024-2025
ChatGPT est devenu un outil très utilisé.
Les LLM fascinent et tout le monde veut intégrer cette techno tendance.
 Outils faciles d’accès : il « suffit » de s’exprimer en langage naturel
 Résultats bluffants : de nombreux exemples de textes ou images générées impressionnent
MAIS les LLM ne sont pas une baguette magique
 Coût d’itération : Les résultats ne sont pas toujours corrects, voire parfois très loin de la réponse attendue. Pour obtenir un
résultat pertinent sur un besoin précis, il est nécessaire d’appeler les LLM de nombreuses fois (nombre rarement précisé).
– Pour la génération de photos pour une exposition « Les ruines de Paris », en moyenne 650 appels à Midjourney ont été nécessaires par photo.
 L’expertise métier reste nécessaire : au lieu de passer par une modélisation formelle type ontologie en entrée, il est proposé
de passer par le langage naturel => pas forcément plus simple et sans doute plus coûteux en calculs
 Coût environnemental : ils sont basés sur un nombre extrêmement élevé de paramètres (7 milliards, 70 milliards…) et de
données d’apprentissage
Importance de l’évaluation de ces technos sur de vrais besoins
 Comparaison avec d’autres approches (symboliques)
Questions ?
48 Thales Research & Technology France trtp version 9.0.0 selon modèle
Élaboration d’un corpus d’apprentissage à partir d’articles de recherche en
chimie
Contexte
 Domaine : chimie des matériaux, pas de corpus annoté préexistant.
 Clients : consortium en chimie, une quinzaine d’expert.es.
 Besoin : extraction de valeurs associées à des propriétés pour différents composants chimiques, à
partir des textes d’articles de recherche.
Quelques étapes
 Construction d’un corpus
– Identification d’un sujet : propriétés mécaniques de composants en lien avec l’acrylonitril butadiène styrène
(ABS).
– Constitution d’un corpus d’articles : 43 documents de 15 pages en moyenne.
– Constitution d’un corpus pour l’annotation manuelle : 89 extraits de 2 à 10 phrases.
ABS
49 Thales Research & Technology France trtp version 9.0.0 selon modèle
Exemples d’extraits textuels à annoter
 Extrait 1 : « … for ABS/graphene composites. Interestingly enough, these composites show elastic modulus of about 7362 MPa and
tensile strength of about 44 MPa. »
 Extrait 2 : « The tensile strength for ABS/ZnO line samples were 23.3, 24.19, and 28.24 MPa for the infill density of 50%, 75%, and 100%,
respectively. For CABS/ZnO line samples, the tensile strength improved 6.3% to 10.31 MPa when infill density changed from 50% to
100%. »
 Extrait 3 : « The set at vp = 5 mm/s has the lowest elastic modulus of E = 1.9–2.0 GPa, while samples fabricated at vp = 20 mm/s have
values around 2.2 GPa. »
50 Thales Research & Technology France trtp version 9.0.0 selon modèle
Modèle d’annotation et exemples d’extraits textuels annotés
Types d’entités : PROP, CHEM, VALUE, COND
Types de relations : has_value, with_condition, is_property_of, measured_at
51 Thales Research & Technology France trtp version 9.0.0 selon modèle
Quelques étapes
Construction d’un corpus
Construction d’un schéma d’annotation
– Difficultés : peu de phrases contiennent toutes les informations visées : valeurs, noms de propriétés,
noms de composants chimiques
- Exemple de composants chimiques visé : « ABS/ZnO » (composant spécifique à un article, absent
des ontologies de chimie type ChEBI)
Post-traitements
– Gestion des valeurs numériques et unités après une annotation manuelle en un bloc des valeurs «
44 MPa », fusions…
52 Thales Research & Technology France trtp version 9.0.0 selon modèle
Des résultats
▌288 extraits annotés obtenus, pas très homogènes.
De 58 extraits distincts bien annotés (environ 270 phrases) :
- Mentions d’entités : 380 Chemistry et Property, environ 600 Condition (forte hétérogénéité) et Value.
- Mentions de relations : environ 200 has_value et with_condition, environ 40 is_property_of et measured_at.
Questions ?
🛩️ 1. Présentation de THALES et du pôle recherche
THALES = acteur majeur dans l’avionique civile et militaire et la gestion du trafic aérien.


Mission principale : détection et collecte de données pour améliorer la prise de décision critique.


Présence internationale : France, UK, Canada, Pays-Bas, Singapour.


Forte activité de R&D :


7 laboratoires, 400 chercheurs et 50 PhD.
20% des activités du groupe dédiées à la recherche.
80 projets collaboratifs (français & européens).
35 doctorants et brevets déposés/an.
Sites clés :


Plateau de Saclay : cœur de la recherche.
CortAIx labs : Digital Factory, Theresis, Sciences & Technologies de l’information.
Nouveau labo ARX (anciennement LRASC).

🧠 2. Domaines de recherche NLP et IA
Principales thématiques
Extraction informations :
Fusion et ontologies → rassembler infos venant de sources différentes sur un même élément.
Knowledge Graph Mining & Reasoning :
Modélisation et structuration des connaissances.
Algorithm Validation :
Vérification et validation des algorithmes.
Hybrid Inference Models :
Combinaison des approches symboliques et statistiques.
Évolution des méthodes
Tendance actuelle : explosion des LLM & Transformers.
Avant : modèles symboliques basés sur des règles.
Aujourd’hui : les approches neuronales explosent, mais leurs limites font que les entreprises reviennent vers des méthodes hybrides.

🎓 3. Parcours académique
Maîtrise MASS (Maths, Info, Éco).
DEA en TAL (équivalent M2 recherche).
Thèse CIFRE (2000) : extraction informations textuelles à partir de brevets pour la veille technologique.

⚙️ 4. Projets en TAL et IA chez THALES
📌 Activités en aide à la décision
Apprentissage de préférences (modélisation des décisions).
Approches mathématiques avancées :
Intégrales de Choquet 2-additive (modélisation de l’incertitude).
Placement de capteurs via algorithmes évolutionnaires.
📌 Projets d’extraction informations
Projet renseignement militaire 🕵️‍♀️


Extraction de relations entre entités nommées (NER + relations).
Utilisation d’Unitex (approche symbolique) :
✅ Explicabilité forte.
❌ Coût élevé, manque de linguistes chez Thales.
Transition vers approches statistiques :
✅ Annotation plus rapide.
❌ Besoin de gros corpus annotés et moins explicable.
Projet TVS (2000-2004) 🎙️


Commande vocale pour l'entraînement des troupes militaires.
Rédaction de grammaires génériques et spécifiques.
Dépôt de brevet (industrie valorise énormément les brevets).
Outilex 📑


Analyse textuelle avec conversion de mots-clés en chaînes de phonèmes.
Gestion de l’incertitude dans les textes (polarité, source, etc.).
SemPlus 🔍


Extraction informations structurées depuis du texte non structuré.
NER + relations binaires (ex : relation contact entre Pauline et Alix).
Difficulté : données brutes sans ponctuation, fautes, acronymes, manque de prépositions.
Approche symbolique améliorée :
✅ Bonne explicabilité.
❌ Problème de généralisation.
Outil repris par la start-up Arisem, intégrée ensuite à Thales.
STRASS (2020 - …) 📈


Extraction de relations entre entités (ex : relation métier-personnes).
Utilisation de SpaCy (passage au Machine Learning).
Problème : clients veulent du ML mais sans corpus annotés.
Cas d’usage : corpus "Predicting Terrorism" (détection nombre de morts/blessés).
Difficulté : forte variabilité des expressions.
Tentative d’intégration à INCEpTION (mais abandonnée).
Approche hybride (symbolique + statistique).

⚡ 5. Impact des Transformers et des LLM
Extraction automatique des relations entre entités.
BERT > autres modèles pour certaines tâches.
GPT : produit beaucoup de résultats mais pas magique.

🏛️ 6. Financement des projets chez THALES
Financements internes 💰 (budget groupe Thales).
Financements externes 🌍 (projets nationaux & européens).

💡 Conclusion
Bénédicte Goujon montre l’évolution du TAL chez Thales, passant de modèles symboliques explicables à des approches hybrides (symbolique + ML).
 Les NER et extraction de relations restent des défis, notamment à cause du manque de corpus annotés et des contraintes métiers.
 Thales explore plusieurs projets en décision, extraction d’info et IA hybride, et bien que les LLM soient à la mode, ils ne remplacent pas totalement les méthodes plus classiques. 🚀
""")

confs.append("""
Traitement des
données textuelles
et orales à EDF
R&D
21/06/2024
Leila Hassani
Ingénieure-chercheuse en Traitement
Automatique du Langage Naturel
Traitements et Innovation pour la valorisation
des données textuelles et Anticipation de
nouvelles technologies (TITAN)
leila.hassani@edf.fr
Qui suis-je ?
Leila Hassani, Ingénieure en Traitement Automatique du Langage Naturel à EDF
Mon parcours :
➢ 2015 : collège // adhésion à l’association BecomTech, qui introduit les jeunes lycéennes (14-18 ans) aux
métiers de la Tech lors d'une formation d'été d'un mois. Participation à des ateliers d’initation au code
et à la communication digitale.
➢ 2017 : Obtention d’un bac S, intégration d’une
➢ 2017-2018 : Césure, enseignement de l'anglais en Corée du Sud
➢ 2018-2020 : Licence de langue & culture coréenne, Paris Diderot
➢ 2020-2021 : Master 1 Traitement Automatique des Langues (TAL), INALCO
➢ Été 2021 : Formatrice informatique pour l'association BecomTech
➢ 2022-2023 : Master 2 Traitement Automatique des Langues (TAL), Paris Nanterre / Ingénieure TAL en
alternance à la R&D d’EDF
➢ Nov. 2023 : Embauche à EDF
Tests R&D
d’outils et méthodes
pour l’exploitation
des données textuelles
La R&D détecte, teste et développe des outils et méthodes
de traitement des données textuelles et orales afin de
venir en appui aux différents métiers du Groupe. Nous
travaillons notamment sur la compréhension et
l’amélioration de modèles de Deep Learning.
3
Améliorer la performance
du Groupe EDF dans toutes ses
activités d’aujourd’hui et en faire
profiter ses clients.
Préparer l’avenir énergétique
en travaillant sur les technologies de
rupture.
Effectuer des recherches pour des
commanditaires externes, dans le cadre
de partenariats ou de commandes.
Les
missions
de la R&D
LA R&D EN CHIFFRES
* 1015 de FLOPS (floating-point operations per second), qui mesure la rapidité de calculs qu’un système peut effectuer
en secondes
*
LA R&D
DANS
LE MONDE
Avec 3 centres en France,
6 à l’étranger et une
délégation à Bruxelles,
EDF conduit ses activités
de recherche à l'échelle
nationale et internationale.
FRANCE
ÉTATS UNIS
ROYAUME UNI
CHINE
ALLEMAGNE
ITALIE
EDF LAB LES RENARDIÈRES
EDF LAB PARIS-SACLAY
EDF LAB CHATOU
SINGAPOUR
BELGIQUE
EDF Lab Paris-Saclay
✓Le plus grand centre R&D d’EDF
✓8 laboratoires
Réalité augmentée au laboratoire ConnexLab de Paris Saclay 7
✓Situé sur le Plateau de Saclay à Palaiseau (pôle
scientifique et technologique)
SEQUOIA
Service, Economie, Questions hUmaines, Outils innovants et IA
Département multidisciplinaire qui réunit quatre pôles de compétences : Sciences Humaines et
Sociales (SHS), les offres et services innovants aux clients, l’économie et la stratégie, et la science des
données (Data Science) et l’intelligence artificielle (IA).
8
LA DATA A SEQUOIA
9
Séries temporelles
Texte
Image
Signal sonore (son, voix)
Vidéo
Predictive modeling Computer Vision / Vision par Ordinateur
Natural Language Processing (NLP) / Traitement Automatique des Langues (TAL)
LES SERIES TEMPORELLES
10
Prévision de la consommation énergétique : permet à EDF de prévoir le besoin d'électricité à un moment T.
Si EDF sait quel sera la consommation de ses clients à un moment donné, elle peut s'assurer de la
continuité de la distribution énergétique. Le stockage de l'énergie a également un coût : prévoir, c'est aussi
éviter d'avoir à stocker plus que nécessaire.
C'est notamment vrai lors de situations de crises ou inhabituelles (ex. COVID, guerre en Ukraine...) qui
impliquent des modélisations différentes.
Séries temporelles
LES IMAGES : DETECTION DE DEFAUTS
11
Image
AI Blade Defects : outil d'IA afin de détecter les défauts des pales d'éolienne à partir de
photographies. Permet d'accélérer les opérations de maintenance ou de prévoir & prévenir
de pannes.
LA MULTIMODALITÉ : VISUAL QUESTION ANSWERING
12
Le matériel est-il cassé ?
Multimodalité : type d’apprentissage qui peux traiter plusieurs types de données différentes en entrée
Oui, le matériel est cassé
Image
Texte
LA MULTIMODALITÉ : VISUAL QUESTION ANSWERING
13
LA MULTIMODALITÉ : L'OCR-ISATION
14
Tâche d’OCR-isation : extraire du texte à partir d’une image.
La reconnaissance de dates manuscrites est une tâche difficile : elle permet d’automatiser
l’extraction d’information contenues dans des formulaires à partir d’images de ces formulaires.
Image
Texte
LES VIDEOS : DETECTION AUTOMATIQUE DE CHUTES
15
Vidéo
Détection automatique de chutes : de nouvelles approches basées sur l'analyse fine (pixel par pixel)
d’images ont été proposées dans la littérature pour la détection de chutes humaines. Ces approches sont
cependant gourmandes et requièrent pour leurs entrainements un nombre assez important d'images/vidéos
ainsi que beaucoup d'heures de calcul. La méthode proposée ici utilise un procédé de détection
automatique de chutes de personne isolée basée sur l’extraction des points du squelette humain, suivie de
l'entrainement de méthodes de classification automatique sur ces points du squelette humain afin d’identifier
les situations de chute. Cette solution est ainsi moins chronophage (elle a besoin de moins de données en
entrée et de moins de temps de calcul) et présente un très bon niveau de performance.
LE TEXTE ET LE SIGNAL SONORE
16
Signal sonore (son, voix) Texte
Un petit focus sur...
Besoins
17
▪ Analyser automatiquement Les données pour différents
métiers :
 Relation Client : Mieux connaître nos clients – EDF Commerce
• appui marketing (réclamation client, Satisfaction client, image
EDF, réseaux sociaux)
• assistance aux conseillers client (traitement des emails,
chatbot)
 Producteurs (éolien, nucléaire, hydraulique etc.)
• Analyse des REX et comptes rendus d’intervention (exploiter
les données pour optimiser les besoins de maintenance)
• Faciliter la professionnalisation par un accès facilité aux
données.
 Répondre aux problématiques RGPD (traitement des données
personnelles)
▪ Fonctionnalités d’intérêt principales
 Classification supervisée et non supervisée
 Génération de texte
 Extraction de connaissance
 Web sémantique
1. Clavier prédictif pour appuyer les conseillers
2. Résumé automatique des notes techniques
de chercheurs
3. Détection automatique de nouveauté dans
des mails clients
4. Retranscription et anonymisation de
conversations téléphoniques
5. Explicabilité des méthodes d’IA pour le texte
Exemples
de sujets
traités
18
Tests de méthodes et outils Deep Learning Appliqués au texte
19
Finalités :
o Apporter une connaissance sur les nouveaux modèles de Deep Learning afin d'améliorer la
performance opérationnelle et le traitement des demandes client.
o Gain de temps pour les conseillers et les data scientist.
o Amélioration de l’image d’EDF (réduction temps de traitement des demandes + amélioration des
écrits).
Comment ?
o Few Shot Learning et Data Augmentation pour réduire le temps d’annotation et améliorer la
performance des modèles de classification sur les classes minoritaires.
o Mécanismes d’attention des modèles Transformers Bert-like – Longfomer.
o Transfer Learning pour l’adaptation de modèles de langue à nos données et l’amélioration de la
chaîne de traitement en place.
o Rédaction d’un rapport annuel de veille sur les nouvelles méthodes et modèles d’IA sur le texte.
Exemples d’application :
o Développement d’un clavier prédictif pour les conseillers avec apprentissage d’un modèle de
langue sur données mails.
o Suggestion de réponses complètes automatiques aux conseillers.
o Tests de méthodes de résumé automatique de texte.
Beltagy, Iz, Matthew E. Peters,
and Arman Cohan.
"Longformer: The longdocument transformer." (2020).
Clavier Prédictif
pour l’aide à la
rédaction de mails
des conseillers
20
Pourquoi un clavier prédictif pour les conseillers ?
Une solution automatique à travers un clavier prédictif en français fournissant des suggestions contextuelles en temps réel.
Améliorer la qualité de
rédaction
Optimiser le temps de
réponse des conseillers
Simplifier le processus
d’écriture de mails tout en
contrôlant la génération
automatique
Réduire l’écriture
répétitive
01 02
04 03
Savoir Faire et Expertise R&D
sur la génération de texte
LOREM IPSUM
LOREN IPSUM
LOREM IPSUM
LOREM IPSUM
2019 2020 2020 2021 2021
Fine-tuning de
GPT2 sur nos
données
Génération automatique de
réponses dans des dialogues
client/conseiller. Le modèle génère
des textes en français correct mais
sa capacité à mémoriser de
l'information est limitée. Au bout
d’une dizaine d’échanges, il produit
des phrases répétitives
Essai de
training d’un
générateur en
français
Test d’un générateur de texte
« générique » sur des données
open source en français sur
des TPUs Google avec le
modèle GPT2. L'infrastructure
nécessaire était trop
importante.
Sortie de
BelGPT-2
Sortie fin 2020 de BelGPT-2
modèle basé sur GPT-2 et
appris sur de français.
Fine-tuning de
BelGPT-2 sur nos
données et training
d’un Transformer
Fine-tuning de BelGPT-2
sur près d’1Milion de mails
conseillers et entraînement
d’un Transformer form
scratch.
Premier clavier
prédictif R&D
pour conseillers
Développement de l’IHM
en cours et tests à venir en
situation réelle.
DÉMARCHE BESOINS
Comment avons-nous pensé le clavier prédictif pour les conseillers ?
23
1 2 3
3
DÉVELOPPEMENT D’UN
DÉMONSTRATEUR WEB
Solution état de l’art et open
source. Objectif : proposer des
suggestions de qualité, rapides
en tempsréel
1
TÂCHE DE GENERATION DE TEXTE
Article Google Smart Compose (2019)
Test de 2 architectures état de l’art
▪ Transformer (2017) : Encodeur
Décodeur non pré-entrainé
▪ BelGPT (2020) : transformer
entrainé en français pour génération
de texte (cf. GPT-2 2019)
2
▪ BelGPT : Fine-tuning avec nos
données du modèle initial.
▪ Transformer Encodeur Décodeur :
Entraîné from scratch à générer du
texte à partir de nos données EDF.
CORPUS DE ~ 1 MILLION MAILS
ANONYMISÉS DE CONSEILLERS
Après entraînement le modèle
connait le vocabulaire métier d’EDF
Capable de reproduire le style
d’écriture des conseillers
Interface facile à prendre
en main pour les conseiller
Architectures des modèles testés
24
02 Pytorch Transformer
03 BelGPT
01 Baseline : modèle de langue N-gramme
• Modèle probabiliste : Calcul de
probabilité d’un mot en se basant
sur un historique de taille N.
• Modèle encodeur décodeur avec une attention :
permet de gérer les dépendances longues entre
les mots. Test from scratch sur nos données EDF,
sans pré-entraînement.
• Modèle décodeur avec une attention :
optimisé pour la génération de texte, basé sur
GPT-2 et appris sur un corpus en français
(~60Gb). Test de fine-tuning sur nos données
EDF.
Résultats Obtenus – Calcul de la Perplexité
25
Modèle Score
Perplexité Nbre GPUs Training Time
BelGPT FT 1.07 20 21h
Transformer 2,9 1 4h
Ngram 50,3 0 NC
Conclusion :
• Bel-GPT2 obtient la meilleure perplexité (mesure l’efficacité de la
distribution de probabilité pour la prédiction du mot suivant : plus
elle est faible, plus le modèle est confiant) et ses résultats dépassent
ceux de l’état de l’art Google.
• Le modèle Transformer obtient également de très bons résultats et
nécessite moins de ressources machine que Bel-GPT2.
• Le modèle N-gramme est largement devancé.
Tableau Résultats EDF Tableau Résultats Article Google
1. Clavier prédictif pour appuyer les conseillers
2. Résumé automatique des notes techniques
de chercheurs
3. Détection automatique de nouveauté dans
des mails clients
4. Retranscription et anonymisation de
conversations téléphoniques
5. Explicabilité des méthodes d’IA pour le texte
Exemples
de sujets
traités
27
Résumer automatiquement
un texte avec des
méthodes abstractives
Gagner du temps et des
connaissances en obtenant
automatiquement une synthèse
de données textuelles
28
articles
scientifiques et
brevets
actualités /
Newsletters
veille
marketing
réunions rapports de
maintenance
document
décrivant nos
installations
Résumé automatique de texte –
Défis techniques et solutions
29
Défis du résumé automatique :
1. Le modèle doit abstraire et restituer les connaissances de façon
intelligible.
2. La taille maximum d’un document prise en entrée par un modèle doit
être conséquente.
• Solutions utilisées à EDF R&D :
• Modèles deep learning traitant des textes longs (~7500 mots) : Modèle
BART + mécanisme d’attention Longformer (Beltagy et al., 2020).
• Exploitation des clusters de calcul haute performance (HPC) EDF.
Mise en place de méthodes de Transfer Learning
30
Données EDF : ~ 1 000 documents
Pour chacun :
• un corps de texte
• un résumé de référence (rédacteur
humain)
Phase d’entraînement sur cluster HPC
(Calcul Haute Performance) CRONOS
Résultats
31
Capacité du modèle à générer des résumés cohérents.
Apparition fréquente de segments des premières phrases du document
Résumé système (généré automatiquement)
Ce document décrit le programme prévisionnel du Laboratoire Commun appelé BILab, créé en 2007 pour une durée de
quatre années.
Résumé de référence (rédacteur humain)
Ce document contient le programme prévisionnel de travail du BILab pour l'année 2008. Le BILab est le Laboratoire
Commun de Business Intelligence crée en 2007 pour quatre années, entre EDF et Telecom ParisTech.
Début du corps du document
Les objectifs du Laboratoire Commun appelé BILab, créé en 2007 pour une durée de quatre années sont les suivants…
Exemple
Limites : il arrive que certains thèmes du documents soient omis ou mal compris.
1. Clavier prédictif pour appuyer les conseillers
2. Résumé automatique des notes techniques
de chercheurs
3. Détection automatique de nouveauté dans
des mails clients
4. Retranscription et anonymisation de
conversations téléphoniques
5. Explicabilité des méthodes d’IA pour le texte
Exemples
de sujets
traités
32
Détection de la nouveauté au plus tôt dans les données textuelles
33
Finalités :
o Trouver des méthodes mettant en avant une thématique émergente avant que celle-ci ne soit identifiée comme
étant un signal fort.
o Accroître la réactivité de la Relation Client face à de nouvelles thématiques jusque-là non ciblées.
Comment ?
o Développement d’un algorithme pour lancer des alertes lors du changement de volumétrie de certaines classes,
indiquant l’apparition d’une anomalie et l’émergence d’une nouvelle classe potentielle.
Exemples d’application :
• Thèse sur le sujet soutenue en 2021.
• Développement d’une plateforme de visualisation
 de l’évolution des données dans le temps (TempoTopic).
1. Clavier prédictif pour appuyer les conseillers
2. Résumé automatique des notes techniques
de chercheurs
3. Détection automatique de nouveauté dans
des mails clients
4. Retranscription et anonymisation de
conversations téléphoniques
5. Explicabilité des méthodes d’IA pour le texte
Exemples
de sujets
traités
34
Développement de méthodes d’apprentissage et de fine tuning
pour l’oral
35
Finalités :
o Conserver une connaissance du marché et l’expertise
sur les méthodes de transcription de l'oral et de
l'anonymisation de ces données.
o Connaître les solutions existantes afin de répondre
aux prochaines problématiques liées aux données
orales.
o Proposer des solutions internes adaptées aux
données du métier.
Exemples d’application :
o Développement d’une plateforme
 de retranscription et d’anonymisation.
Comment ?
o Benchmark des solutions existantes.
o Développement d’une chaîne de retranscription basée
sur des outils open-source.
o Développement d’un modèle de langue sur données
EDF.
o Intégration de modules d’anonymisation à la chaine de
traitement.
Méthodologie & Chaîne de traitement
36
Signal audio 2. Alignement
des mots
Pour chaque mot
transcrit:
- À quel moment
apparait le mot dans
l’audio
- La durée en seconde
du mot dans l’audio
1. Transcription
Transformation
de audio en
texte
3. Détection
automatique des
DCP
Lancer le modèle
de détection
d’entité nommées
Signal audio
anonymisé
4. Bip sur
les DCP
Reconnaissance automatique de la parole (ASR)
Challenges
37
Prétraitement du signal
- Numérisation du signal audio
- Supprimer le bruit Phonétique
La variabilité de la parole humaine
(genre, âge, accent)
Caractérisation physique des sons
Phonologie
Reconnaître les distinctions sonores
individuelles (phonèmes similaires : é /
ai)
Calcul de probabilité pour retrouver des
mots.
Syntaxe et pragmatisme
− Interprétation des caractéristiques
prosodiques
− Filtrage des erreurs de performance
(disfluences)
Lexicologie et syntaxe
− Dissiper l'ambiguïté des
homophones
− Caractéristiques de la parole
continue (tours de parole)
01
02
03
04
05
Système de reconnaissance vocale
38
a) Données audio avec leurs transcriptions
b) Lexique de prononciation
c) Choix de l'unité de sous-mots (ex : phonèmes, graphèmes)
d) L'extraction des features inclut généralement MFCC
1. Préparation des données et extraction des features
• Modèle statistique pour apprendre les relations entre les
sous-mots (phonèmes) et le signal audio.
• Plusieurs algorithmes sont proposés par les outils afin
d’apprendre: convolution, RNN, Connectionist Temporal
Classification (CTC), TDNN.
• Sortie: le modèle calcule la probabilité du signal audio
compte tenu des sous mots.
2. Entrainement du modèle acoustique
Cette partie nécessite l’utilisation des éléments suivants :
• Lexique
• Le modèle de langage
• Le modèle acoustique
Le lexique de prononciation : Les mots et leurs prononciations
fournissent le lien entre le modèle acoustique de sous-mots et
les modèles de langue.
Construction d’un lexique :
➢ Sélection des mots dans le dictionnaire - souhaite assurer
une couverture élevée des mots dans les données de test.
➢ Représentation de la ou des prononciation (s) de chaque
mot.
Le modèle de langage : Calcule la probabilité d'une séquence
de mots. Généralement, en utilisant des n-gram.
3. Décoder le signal audio
Exemple de retranscription avec l’ASR Zamia
La cliente mme mérite botia appel car elle vient de recevoir sa facture de souscription qu'elle s'était aperçu
qu'il y a une erreur sur les relevés de compteur car pour elle nous avons pris les relevés estimé de l'ancienne
propriétaire mme manelle bulgare elle constate qu'il y a effectivement une grosse différence entre les
relevés de l'acte de vente de la cliente et ce sur la facture n° trente-cinq zéro zéro six cent dix-sept
huit cent dix-sept je lui propose de nous envoyer de l'acte de vente du sept bd gaspard mangent à
palaiseau de façon à ce qu'on puisse faire un redressement la cliente est satisfaite de la réponse à apporter
aux zéro six cinquante-deux soixante-dix-sept quarante-trois quatre-vingt-douze son point de
livraison et vingt-trois vingt treize zéro deux quarante-trois quatre-vingt-douze quarante
39
Transcription
Amélioration des performances du modèle
open source Linagora LinTO par adaptation
des corpus génériques puis
réapprentissage par Transfer Learning avec
des corpus spécifiques EDF (conseillers
clients, documents EDF).
5. Bench des Solutions de speech-to-text et développement d’un ASR EDF
0,418
0,335
0,266
0,211
La métrique de performance mesurée
est le Word Error Rate (WER) :
1. Clavier prédictif pour appuyer les conseillers
2. Résumé automatique des notes techniques
de chercheurs
3. Détection automatique de nouveauté dans
des mails clients
4. Retranscription et anonymisation de
conversations téléphoniques
5. Explicabilité des méthodes d’IA pour le texte
Exemples
de sujets
traités
44
Explicabilité des méthodes d’IA pour le texte
45
Finalités :
o Permettre aux data scientists de mieux comprendre les résultats des modèles Deep
Learning.
o Améliorer les modèles d’apprentissage et en assurer la robustesse/généricité.
o Veiller à l’équité de traitement client et à l’éthique des modèles.
Comment ?
o Etat de l’art et développement d’attaques adverses sur des modèles de langue : perturber la
prédictions des modèles et évaluation des nouveaux scores.
o Lancement d’une thèse en 2020 sur l’étude des biais dans les modèles de langue.
o Mise en place de méthodes de débiaisage pour le français.
o Préconisations R&D pour se prémunir contre les attaques : augmentation de données et
monitoring de modèles dans le temps.
Exemples d’application :
• Proposition d’une méthode pour le renforcement de la compréhension du vocabulaire
métier des modèles de langue (BERT-Like) par injection d’information morphosyntaxique et
sans fine-tuning – Soumission d’un article.
• Audit de Kitten - module de désidentification.
Clustering avec visualisation t-SNE des
mots contenus dans les mails EDF –
CamemBERT en haut vs CamemBERTEDF en bas
Détail par lot et livrable
Lot 1 - Evaluation de méthodes, outils
et solutions
01
02
03
04
Besoins identifiés à date
1 Monitoring des modèles
2
Briques de Speech Analytics et Speech to Text :
Apprentissage et Fine-Tuning pour l'oral / Anonymisation
retranscriptions et voix
3 Reconnaissance Automatique de dates
4 Détection de documents sensibles
Détail par lot et livrable
01
02
03
04
Lot 2 - Veille, IA et Explicabilité
des modèles pour le texte et l'oral
1 Newsletter DL - données non structurées - LP P1
2 IA pilotée par les données P1
3 Veille text mining - Alternance P1
4
Réduire les temps d'annotation de données tout en
assurant leur qualité P1
5 Thèse sur les biais dans les modèles de langue P1
6
Thèse sur le Traitement de séquence textuelles
longues par réseaux de neurones profonds et
mécanismes d’attention
P1
7 Informatique Quantique pour le texte P2
8 Exploration de données P2
9 Graphes GNN P2
Détail par lot et livrable
01
02
03
04
Lot 3 - Développement de méthodes
et boîte à outil pour le texte
1 Méthodes sur données mixtes P1
2 Prompt Learning - LP P1
3 Green AI P2
4 Résumé automatique de texte P2
01
02
03
04
Lot 4 - Animation du réseau text mining
Détail par lot et livrable
Séminaire text-mining, participation à des
conférences, partenariats
Défi EGC 2023
Défi Fouille de Texte 2023 - Conférence TALN
En résumé
1. REGEX - BASH
2. PYTHON
3. EXTRACTION DE CONNAISSANCE
4. LLM - TRANSFORMERS
5. PHONÉTIQUE, TRAITEMENT DE L’AUDIO
6. LA GESTION DE PROJET
7. GIT
8. UN PEU D’ARCHI
9. DEEP LEARNING MAIS PAS QUE …
Merci

🔬 1. Parcours et rôle chez EDF
Parcours académique et professionnel :


Bac S → prépa commerce → Master TAL → alternance EDF → CDI à Saclay.
Intérêt marqué pour la computer vision en plus du NLP.
EDF : un grand groupe avec de nombreuses opportunités :


R&D = développement d’outils et méthodes de traitement du langage et des données multimodales.
Focalisation sur l’amélioration des modèles de Deep Learning.
Missions de la R&D chez EDF :


Optimiser la performance de l’entreprise.
Préparer l’avenir énergétique.
Effectuer des recherches pour des commanditaires externes.
Saclay = plus grand centre de R&D d’EDF.


Département SEQUOIA (Service, Économie, Questions Humaines, Outils innovants et IA) :


Predictive Modeling (séries temporelles).
Computer vision.
NLP.

📊 2. Thèmes de recherche et projets en IA
📈 Séries temporelles & predictive modeling
Prévision de la consommation énergétique.
Domaine IA très mathématique, différent du NLP.
🖼️ Computer vision et Visual Question Answering
VLM (Visual Language Model) = fusion image + texte.
Ex : Analyse automatique d’images pour détecter des anomalies (ex : matériel endommagé).
Détection automatique de chutes :
Sécurisation des travailleurs isolés.

🗂️ 3. Applications du TAL chez EDF
Analyse automatique des données pour plusieurs métiers :


Relation client (appui marketing, assistance aux conseillers).
Producteurs (optimisation de la gestion des ressources).
RGPD & anonymisation (sécurisation des données clients).
Principales fonctionnalités NLP :


Classification (supervisée et non supervisée).
Génération de texte.
Extraction de connaissances.
Web sémantique :
Structuration des données pour LLMs.
Retour des approches symboliques en complément des LLMs.
Exemples de projets NLP :
Clavier prédictif :


Entraîné sur 1M d’échanges clients.
Suggestion de phrases entières.
Fine-tuning nécessaire pour adapter au vocabulaire EDF.
Résumé automatique :


Approche extractive : sélection des phrases clés (souvent au début/fin du texte).
Approche abstractive : reformulation intelligente.
Anonymisation des documents :


Sécurisation des données sensibles (ex : documents d’identité).
Création de fausses pièces d’identité pour tester la robustesse des systèmes.

🔍 4. Tests et recherche sur le Deep Learning
Objectifs des tests de méthodes DL appliquées au texte :


Comprendre et évaluer les nouveaux modèles DL.
Optimiser le temps des conseillers et data scientists.
Améliorer l’image d’EDF sur le plan technologique.
Approches explorées :


Few-shot learning & data augmentation.
Transformers BERT-like (Longformer).
Transfer learning.
Score de perplexité :
Mesure de la fluidité d’un texte (bas = généré par IA, haut = humain).
Méthodes pour tester la récupération information :


"Needle in a haystack" = insérer une info dans un corpus et vérifier si le modèle la retrouve.

🏛️ 5. Applications sociologiques et nouvelles perspectives
Études sociologiques sur le nucléaire :


Monitoring de l’opinion publique.
Optimisation de la relation client.
Modèles de diffusion d’images (ex: Dali) :


Génération d’images à partir de prompts.
Modification automatique d’éléments.
POC (Proof of Concept) :


Tests de solutions IA sur courte période avant décision de déploiement.

💡 Conclusion
Leila Hassani montre un large spectre d’applications du NLP chez EDF, allant de l’optimisation énergétique, à la relation client, en passant par l’anonymisation des données et la computer vision.
 EDF explore les méthodes mixtes (LLM + symbolique) et mène une veille technologique sur les modèles DL pour améliorer la gestion et la sécurité des données. ⚡
""")

confs.append("""
🧠 1. Domaine de recherche : Passage à l’échelle en TAL et recherche information
Travaille sur la compréhension de la parole et des moteurs de recherche.
Approches multilingues et multimodales (texte et parole).
Évaluation de la qualité des modèles NLP.

📌 2. Représentation et traitement du langage
Représentation continue des mots :


Word embeddings : word2vec, GloVe, FastText.
Attention & Transformers : amélioration de la compréhension contextuelle.
frALBERT : modèle plus léger que Camembert mais aux performances similaires.
Applications NLP :


Détection d’intention et extraction information.
Analyse de sentiment & analyse des réseaux sociaux.
Compréhension en lecture.
Détection d’intention :


Ex : "Quel est le temps à Paris ?"
Quel → label de question
À Paris → label de localisation
Temps → label d’objet
CER (Concept Error Rate) :


Mesure d’erreur dans la reconnaissance et l’extraction informations.
Fine-tuning BERT :


Performant mais difficilement industrialisable en raison du coût élevé.

🔎 3. NLP & Moteurs de recherche
Tendances actuelles :


Détection d’anomalies : variations dans les requêtes et contenus (burstiness).
Détection de thématiques : catégorisation des sujets.
Optimisation des requêtes : aide l’utilisateur à formuler la meilleure question.
Traduction automatique :


Modèles séquence à séquence & Transformers.
Amélioration continue :
Meilleure gestion des pronoms, domaines spécifiques, cohérence de document.
Requêtes multilingues :


Embeddings multilingues :
BIVEC : apprentissage de représentations bilingues.
MUSE : alignement cross-lingue.
QISS (requêtes multilingues et multimodales) :
Unification dans un espace commun pour rechercher des documents.

🏗️ 4. Traitement des données & Apprentissage supervisé
Traitement des données :


50 à 80% du temps d’un projet NLP est consacré au data cleaning.
Pipelines récurrents : traitement quotidien ou hebdomadaire.
Apprentissage continu : mise à jour fréquente des modèles.
Apprentissage faiblement supervisé :


Extraction automatique informations.
Utilisation de logs utilisateurs pour l’amélioration.
Clustering & Bootstrapping :
Apprentissage progressif avec ajustements manuels.
Humain dans la boucle :


Correction des erreurs pour améliorer les modèles.

🔥 5. Nouvelles tendances et évolutions des modèles
Minimisation des frontières entre recherche information et TAL.
RAG (Retrieval-Augmented Generation) :
Apporte des sources externes aux LLM pour améliorer les réponses.
Développement d’architectures spécialisées :
"Encoder only" vs. "Decoder only".
Large Agent Models (LAM) → revival des systèmes multi-agents.

🕰️ 6. Histoire et évolution des modèles NLP
Repères historiques :


1947 → Alan Turing.
1948 → Théorie de l’information (Claude Shannon).
1966 → ELIZA (MIT).
1980 → Modèles N-grammes.
2011 → IBM Watson.
2017 → Attention is all you need (Transformer).
2018 → BERT / GPT-1.
Types de modèles de langage :


Modèles prédictifs → utilisent le contexte gauche.
Modèles masqués → utilisent le contexte gauche et droit.

🤖 7. Intelligence Artificielle & Agents
Large Language Models (LLM) :


Large = à partir de 225M de paramètres.
Instruct-LLM : fine-tuning sur des tâches précises.
Agents intelligents (70s) :


PERSISTENCE : tournent en continu.
AUTONOMY : capacité d’auto-organisation.
SOCIAL ABILITY : communication entre agents.
REACTIVITY : réponse aux stimuli en temps réel.
Systèmes multi-agents (Ferber, 1999) :


Plateformes collaboratives où plusieurs agents interagissent.
De plus en plus intégrés aux LLMs modernes.

🔗 8. Open Web UI & Nouveaux outils
Open Web UI : plateforme open-source pour interagir avec LLMs.

💡 Conclusion
Christophe Servan met en avant l’évolution du TAL et des moteurs de recherche, en insistant sur :
L’impact des transformers et des RAG sur le question-answering.
L’intégration progressive de systèmes multi-agents dans les LLMs.
Les défis liés à l’apprentissage supervisé et au traitement des données.
Les avancées en NLP multilingue et multimodal.
Les LLMs et agents intelligents convergent, laissant entrevoir un retour des systèmes collaboratifs dans l’IA. 🚀
Passage à l’échelle d’approches du
TAL et de la RI
Recherche d’information
&
Traitement Automatique des langues
À travers divers cas pratiques
Christophe SERVAN, PhD
Consultant Expert IA,
Chercheur Senior au LISN-CNRS
Mail: christophe.servan@lisn.fr
Christophe Servan, PhD
2
ATALA
Association pour le
Traitement Automatique
des Langues
PhD, 2005-2008
2009
2010 2013
2015
2016
2018
2022
Association Francophone de
Recherche d’Information (RI) et
Applications
Innovation
• Sémantique : systèmes de dialogue, moteur de recherche,
en langue naturelle
• Multilingue & multimodal : demandes et réponses dans
différentes langues sur du texte et de la parole (un peu
d’image…)
• Qualitatif : Evaluations de la qualité des modèles et des
approches
3
Traitement Automatique des Langues
• Le NLP et le Deep Learning sont essentiels pour un moteur de recherche
• Intégration de dans le moteur de recherche à travers le traitement des documents et des
requêtes :
• Reconnaissance d’Entités Nommées (REN) comme les dates, localisations, noms, etc.
• Compréhension de la langue naturelle (NLU) la partie sémantique
• Détection d’intention
• Traduction Automatique
• Question/Réponses
• Reconnaissance Automatique de la Parole
• Affichage / génération d’une réponse
4
« Lotus car price »
Query
processing
Document
processing
Document /
Web pages
Index
Search
engine
Word Embeddings
Représentation continue des mots
• Idée principale :
 Avoir une représentation numérique souple et exploitable des mots
• Solution :
 Projeter les mots dans un espace mathématique à n-dimensions
• binaire
• scores (Tf-IdF)
• scores + compression (réseaux de neurones)
5
 un mot = un vecteur
Word Embeddings
Word embeddings avec des réseaux de neurones
• Idée principale :
➢ « Dis moi quels sont tes amis, je te dirais qui tu es !»
• Solution :
• Plusieurs approches :
• Word2vec
• Glove
• FastText
• …
6
Word Embeddings
Word embeddings avec des Transformers (BERT) [Delvin et al.,
2019]
• Idée principale :
➢ Contextualisation combinées à la notion d’Attention
• Problématique :
➢ Modèles lourds et compliqués à mettre en production
• Solutions :
Optimisation des modèles (Quantification, réduction de paramètres, …)
Création d’un modèle compact pour le Français (frALBERT) [Cattan et al., 2021]
7
Détection d’intention: classification légère
Principale approches explorée:
• Une couche simple + h-softmax + dropout
 mis en production pour la détection d’intention & le shopping
8
[Maudet et Servan, 2020]
Analyse de Sentiments
Problème de classification :
• Message
• Text
• etc.
Analyse de reseaux sociaux :
• Information extraction
• Trends
• etc.
9
Nikola Tesla (en serbe cyrillique : Никола Тесла), né le 10 juillet 1856 à Smiljan dans
l'Empire d'Autriche (actuelle Croatie) et mort le 7 janvier 1943 à New York, est un inventeur
et ingénieur américain d'origine serbe. Il est notoirement connu pour son rôle prépondérant
dans le développement et l'adoption du courant alternatif pour le transport et la
distribution de l'électricité.
10 Juillet 1856
« Nikola Tesla est né le 10 juillet 1856 »
Compréhension en lecture
• Requête : Quand est né Nikola Tesla ?
10
Compréhension en lecture
• Sujet d’une thèse industrielle
• Utilisation de l’approche Transformers
• Lier les contextes et les questions
[Cattan et al., 2021]
• Création d’un modèle compact
industrialisable : FrALBERT
• https://huggingface.co/qwant/fralbert-base
11
Extraction d’Information
12
Requête: Quel est le temps à Paris ?
label de
Question
label d’Object
label de
Localisation
Document:
Extraction d’Information
• Utilisation de réseaux de neurones
 Approche fondée sur la traduction
(séquence-à-séquence)
• Modèle inspiré de [Ma and Hovy, 2016]
• Meilleures performances obtenues sur
les tâches de compréhension (ATIS,
MEDIA, DEFT 2019)
 Mis en production dans Qwant MAPS
13
[Maudet et al., 2019]
[Ghannay et Servan, 2020]
Détection des tendances (News)
• Exploration d’approche fondée sur la
détection d’anomalie (Burstiness)
• Traitement combiné avec de la détection
de thèmes (sport, politique, etc.)
• Traitement sur les mots uniquement,
évolution proposée sur les Entités
Nommées
14
Détection des tendances (News)
• Exploration d’approche fondée sur la
détection d’anomalie (Burstiness)
• Traitement combiné avec de la détection
de thèmes (sport, politique, etc.)
• Traitement sur les mots uniquement,
évolution proposée sur les Entités
Nommées
15
Auto-correction et Auto-suggestion
• Guider l’utilisateur dans l’écriture de la
requête
• Proposer une requête plus adéquate
• Approche fondée sur les arbres de
segments
• Combinaison avec une approche d’autocorrection
16
Traduction Automatique Neuronale
• Approche Séquence-à-Séquence
• Avec des modèles d’attention [Sutskever et al., 2014]
• Modèles « Transformer » (a.k.a full attention model) [Vaswani et al., 2017]
17
Traduction Automatique de documents
• Approche Transformers
• Ajout d’une représentation de document [Macé et Servan, 2019]
• Améliorations observées :
• Traduction de pronoms
• Informations induites au niveau du context local de la phrase et à longue
distance (peut être au début du document)
• Au niveau lexical:
• Thème ou domaine du document
• Adaptation automatique au document
• Adaptation au niveau de langue
• Approche many-to-one appliquée pour la création d’une
Preuve-de-Concept.
18
Requêtes multilingues
Approches sur les embeddings multilingues:
• BIVEC
• Apprentissage joint de représentations
de mots pour deux langues
• MUSE
• Apprentissage indépendant des langues
• Alignement cross-lingue
19
QISS: Requêtes multilingues et multimodales
20
[Portaz et al.,2019]
Processus d’apprentissage
• Traitement des données
• Apprentissage faiblement supervisé
• Bootstrapping
• Apprentissage continu
21
Traitement des données
• Data Processing :
• Traitement et analyse des données (click-logs, docs, requêtes, etc.)
• Traitement continu des données :
• Pipelines de traitement récurrents (tous les jours, les semaines, etc.)
• Apprentissage continu des modèles
• Pipeline d’apprentissages pour les modèles en production
22
Apprentissage faiblement supervisé
• Extraction automatique d’informations
• Query & clic logs, bases de connaissances, etc.
• Génération automatique d’exemple à partir de patrons
(template) ou de LLM
• Restaurant ${CITY}
• Clustering
• Extraction automatique de partition
• Sélection manuelle de partition
 Human in the loop
23
Bootstrapping
• A partir d’une faible quantité de données
• Apprentissage et évaluation (vérification)
• Appliquer le nouveau modèle
(nouvelles données extraites)
• Filtrage / Sélection / corrections
• Création d’un nouveau corpus d’apprentissage
24
Création de
données
Apprentissage
Evaluation
Extraction de
nouvelles
données
Filtrages des
données
Apprentissage continu / par renforcement avec humain dans la boucle
• Modèles en production
• Extraction des retours utilisateurs
• Collecte et filtrage des données
• Préparation des données
(Automatiques et a priori)
• Adaptation des modèles
25
Modèle en
ligne
Retours
utilisateurs
Collecte de
données
Préparation
des données
Adaptation
du modèle
Données
a priori
Nouvelles tendances
• Frontière RI et TAL mince :
• RAG (Retreival Augmented Generation)
• Approches décoder-only ou génératives (GPT)
• Génération de texte, résumé, traduction automatique
• Approches encoder-only ou discriminantes (BERT-classique)
• Classification, extraction d’information, etc.
• Modèles frugals (ALBERT, ModernBERT, DeepSeek)
• Utilisation de méthodes de compression (ollama, llama.cpp…)
26Considerations after the impact of Large Language Models
and the arrival of Large Agent Models: towards a revival of
multi-agent systems in AI?
M2 TAL, Universit´e Paris Nanterre
Christophe Servan, PhD
Universit´e Paris-Saclay, CNRS, LISN, 91405 Orsay, France,
christophe.servan@lisn.upsaclay.fr
03rd of February 2025
Plan
1. Introduction
2. Language Models
3. Fine-tuning of Neural Language Models
4. Declination of Neural Language Models
5. LLMs in the industry
6. What next? Agent systems!
7. Link LLM & Agents
8. What’s next?
1
Introduction
A bit of Hystory... wait, what?!
1947
Turing Lecture
"Can computer
be intelligent?"
1948
"A Mathematical
Theory of
Communication", by
Claude Shannon
1956
"Artificial
Intelligence", by
Minskly et. al.
1966
ELIZA at MIT
1980
N-gram models
(HMM)
2011
IBM WATSON
2013
CSLM by H.
Schwenk
2017
“Attention is all
you need!” by
Waswani et. al.
2018
BERT model by
Devlin et. al.
GPT-1
2019
GPT-2
2020
GPT-3
2022
BLOOM
GPT-3.5
ChatGPT
2023
Llama
GPT-4
Llama 2
Claude 1 & 2
Gemini
2024
Claude 3
…
2
Language Models
Language Models
Predictive models
• Uses left context to guess the next word
input: [CLS] the man went to
input: [CLS] the man went to the
input: [CLS] the man went to the store
input: [CLS] the man went to the store [SEP]
Masked models
• Uses left and right contexts to guess the word
input: [CLS] the man [MASK] to the store [SEP]
input: [CLS] the man went [MASK] the store [SEP]
input: [CLS] the man went to [MASK] store [SEP]
input: [CLS] the man went to the [MASK] [SEP]
3
Language Models
• Statistical Language Models since 80’s (HMM)
• include in many tasks:
◦ Machine Translation [Koehn et al., 2003]
◦ Speech Recognition [Povey et al., 2011]
◦ Spoken / Natural Language Understanding [Servan et al., 2006]
◦ Any log-linear model
4
Back to the time-line
1947
Turing Lecture
"Can computer
be intelligent?"
1948
"A Mathematical
Theory of
Communication", by
Claude Shannon
1956
"Artificial
Intelligence", by
Minskly et. al.
1966
ELIZA at MIT
1980
N-gram models
(HMM)
2011
IBM WATSON
2013
CSLM by H.
Schwenk
2017
“Attention is all
you need!” by
Waswani et. al.
2018
BERT model by
Devlin et. al.
GPT-1
2019
GPT-2
2020
GPT-3
2022
BLOOM
GPT-3.5
ChatGPT
2023
Llama
GPT-4
Llama 2
Claude 1 & 2
Gemini
2024
Claude 3
…
5
Back to the time-line
1947
Turing Lecture
"Can computer
be intelligent?"
1948
"A Mathematical
Theory of
Communication", by
Claude Shannon
1956
"Artificial
Intelligence", by
Minskly et. al.
1966
ELIZA at MIT
1980
N-gram models
(HMM)
2011
IBM WATSON
2013
CSLM by H.
Schwenk
2017
“Attention is all
you need!” by
Waswani et. al.
2018
BERT model by
Devlin et. al.
GPT-1
2019
GPT-2
2020
GPT-3
2022
BLOOM
GPT-3.5
ChatGPT
2023
Llama
GPT-4
Llama 2
Claude 1 & 2
Gemini
2024
Claude 3
…
5
Fine-tuning of Neural Language Models
Language Models: transfert learning
• Transformer models [Vaswani et al., 2017]
• Transfert learning with BERT [Devlin et al., 2019]
6
Language Models: transfert learning
• Transformer models [Vaswani et al., 2017]
• Transfert learning with BERT [Devlin et al., 2019]

 Game changer, introducing the nowaday well-known fine-tuning phase
6
Language Models: transfert learning
Many tasks:
• token classification: NER, POS-tagging, slot-filling...
• sentence classification: intention detection, sentiment analysis...
• span detection: Question-Answering...
• text generation: summarization, response generation...
• etc
7
Language Models: transfert learning
Many tasks:
• token classification: NER, POS-tagging, slot-filling...
• sentence classification: intention detection, sentiment analysis...
• span detection: Question-Answering...
• text generation: summarization, response generation...
• etc
7
Back to the time-line
1947
Turing Lecture
"Can computer
be intelligent?"
1948
"A Mathematical
Theory of
Communication", by
Claude Shannon
1956
"Artificial
Intelligence", by
Minskly et. al.
1966
ELIZA at MIT
1980
N-gram models
(HMM)
2011
IBM WATSON
2013
CSLM by H.
Schwenk
2017
“Attention is all
you need!” by
Waswani et. al.
2018
BERT model by
Devlin et. al.
GPT-1
2019
GPT-2
2020
GPT-3
2022
BLOOM
GPT-3.5
ChatGPT
2023
Llama
GPT-4
Llama 2
Claude 1 & 2
Gemini
2024
Claude 3
…
8
Back to the time-line
1947
Turing Lecture
"Can computer
be intelligent?"
1948
"A Mathematical
Theory of
Communication", by
Claude Shannon
1956
"Artificial
Intelligence", by
Minskly et. al.
1966
ELIZA at MIT
1980
N-gram models
(HMM)
2011
IBM WATSON
2013
CSLM by H.
Schwenk
2017
“Attention is all
you need!” by
Waswani et. al.
2018
BERT model by
Devlin et. al.
GPT-1
2019
GPT-2
2020
GPT-3
2022
BLOOM
GPT-3.5
ChatGPT
2023
Llama
GPT-4
Llama 2
Claude 1 & 2
Gemini
2024
Claude 3
…
8
Predictive Language Models: Generative Pre-trained Transformer
Many tasks:
• introduced by OpenAI in 2018
• enable to generate sequence of token according a query (called prompt)
• transfert learning to specify the generation (intructGPT)
• etc
9
Back to the time-line
1947
Turing Lecture
"Can computer
be intelligent?"
1948
"A Mathematical
Theory of
Communication", by
Claude Shannon
1956
"Artificial
Intelligence", by
Minskly et. al.
1966
ELIZA at MIT
1980
N-gram models
(HMM)
2011
IBM WATSON
2013
CSLM by H.
Schwenk
2017
“Attention is all
you need!” by
Waswani et. al.
2018
BERT model by
Devlin et. al.
GPT-1
2019
GPT-2
2020
GPT-3
2022
BLOOM
GPT-3.5
ChatGPT
2023
Llama
GPT-4
Llama 2
Claude 1 & 2
Gemini
2024
Claude 3
…
10
Back to the time-line
1947
Turing Lecture
"Can computer
be intelligent?"
1948
"A Mathematical
Theory of
Communication", by
Claude Shannon
1956
"Artificial
Intelligence", by
Minskly et. al.
1966
ELIZA at MIT
1980
N-gram models
(HMM)
2011
IBM WATSON
2013
CSLM by H.
Schwenk
2017
“Attention is all
you need!” by
Waswani et. al.
2018
BERT model by
Devlin et. al.
GPT-1
2019
GPT-2
2020
GPT-3
2022
BLOOM
GPT-3.5
ChatGPT
2023
Llama
GPT-4
Llama 2
Claude 1 & 2
Gemini
2024
Claude 3
…
10
Then came the LLM
Rebranding Pre-trained Transformer models as Large Language Models
• what does mean “Large”?
11
Then came the LLM
Rebranding Pre-trained Transformer models as Large Language Models
• what does mean “Large”?
⇒ according [Shoeybi et al., 2019] from GPT-2 (225 Millions parameters)
11
Then came the LLM
Rebranding Pre-trained Transformer models as Large Language Models
• what does mean “Large”?
⇒ according [Shoeybi et al., 2019] from GPT-2 (225 Millions parameters)
⇒ BERT-large [Devlin et al., 2019] (336 Millions parameters)
11
Then came the LLM
Rebranding Pre-trained Transformer models as Large Language Models
• what does mean “Large”?
⇒ according [Shoeybi et al., 2019] from GPT-2 (225 Millions parameters)
⇒ BERT-large [Devlin et al., 2019] (336 Millions parameters)
• are “classical” BERT models with 110M parameters are small?
11
Then came the LLM
Rebranding Pre-trained Transformer models as Large Language Models
• what does mean “Large”?
⇒ according [Shoeybi et al., 2019] from GPT-2 (225 Millions parameters)
⇒ BERT-large [Devlin et al., 2019] (336 Millions parameters)
• are “classical” BERT models with 110M parameters are small?
⇒ actually... No.
11
Then came the LLM
Rebranding Pre-trained Transformer models as Large Language Models
• what does mean “Large”?
⇒ according [Shoeybi et al., 2019] from GPT-2 (225 Millions parameters)
⇒ BERT-large [Devlin et al., 2019] (336 Millions parameters)
• are “classical” BERT models with 110M parameters are small?
⇒ actually... No.
• maybe we should consider the definition according to the amount of
computationnal resources...
11
Then came the LLM
12
Generative LLMs
Many tasks:
• Proposed by OpenAI in 2018
• Decoder-only oriented models
• Able to generate a sequence of token from a text or query (called prompt)
• Adapted to many generation tasks (intructGPT ⇒ ChatGPT)
• etc
13
Declination of Neural Language Models
Then came the instruct–LLM
Fine-tuning of LLM to generate sequence of tokens from sequence of tokens:
• instruct-GPT
• ChatGPT
• BloomZ
• etc.
14
Then came the instruct–LLM
Fine-tuning of LLM to generate sequence of tokens from sequence of tokens:
• instruct-GPT
• ChatGPT
• BloomZ
• etc.

 User’s game changer ⇒ non-expert people can use and exploit LLM
14
Then came the instruct–LLM
Fine-tuning of LLM to generate sequence of tokens from sequence of tokens:
• instruct-GPT
• ChatGPT
• BloomZ
• etc.

 User’s game changer ⇒ non-expert people can use and exploit LLM

 User’s behavior drift...
14
Then came the instruct–LLM
Definition of new practices and methods:
• prompt-engineering
• prompt-tuning
• prompt-generation (by LLM)
• etc.
15
Then came the instruct–LLM
Definition of new practices and methods:
• prompt-engineering
• prompt-tuning
• prompt-generation (by LLM)
• etc.

 begining of the idea of human-computer interaction optimization
15
LLMs in the industry
How are applied LLMs in the industry?
Fine-tuning applied to:
• token classification: NER, POS-tagging, slot-filling...
• sentence classification: intention detection, sentiment analysis...
• span detection: Question-Answering...
• etc
Prompting LLM applied to:
• token classification: NER, POS-tagging, slot-filling...
• sentence classification: intention detection, sentiment analysis...
• Document classification
• text generation: summarization, response generation...
• etc
16
Applications
Named Entity recognition / Part-of-Speech tagging
• Fine-tuning
17
Applications
Document classification
• vectorization (via LLMs)
• classifier
18
Applications
Retrieval Augmented Generation (RAG)
• spoken and Natural Language Question-Answering system
• augmented search engine
19
What next? Agent systems!
What is an “Agent?”
• persistence (code is not executed on demand but runs continuously and decides
for itself when it should perform some activity)
• autonomy (agents have capabilities of task selection, prioritization, goal-directed
behavior, decision-making without human intervention)
• social ability (agents are able to engage other components through some sort of
communication and coordination, they may collaborate on a task)
• reactivity (agents perceive the context in which they operate and react to it
appropriately).
20
What is an “Agent?”
• all agent are program but all programs are not agent
[Franklin and Graesser, 1996]
• agents are not objects [Wooldridge, 2009]
• agents are not expert systems [Wooldridge, 2009]
• agents may be machines, human beings, communities of
human beings or anything that is capable of
goal-directed behavior [Russell and Norvig, 2003]
21
What is an “Agent?”
• all agent are program but all programs are not agent
[Franklin and Graesser, 1996]
• agents are not objects [Wooldridge, 2009]
• agents are not expert systems [Wooldridge, 2009]
• agents may be machines, human beings, communities of
human beings or anything that is capable of
goal-directed behavior [Russell and Norvig, 2003]

 within an environment, with other agents: a multi-agent system
21
Multi-Agent Systems [Ferber, 1999]
• an eco-system of several agents which interact with
one-another
• agents collaborate to complete a task
• act on behalf of users with different goals and
motivations
• they must cooperate, coordinate and negociate to
successfully interact
22
Multi-Agent Systems [Ferber, 1999]
• an eco-system of several agents which interact with
one-another
• agents collaborate to complete a task
• act on behalf of users with different goals and
motivations
• they must cooperate, coordinate and negociate to
successfully interact

 specialized LLMs which communicate with one-another to achieve a goal...
22
Interaction in close environments: video games
• an eco-system of several agents which interact with
one-another
• agents collaborate to complete a task
• act on behalf of users with different goals and
motivations
• they must cooperate, coordinate and negociate to
successfully interact
23
Generative Agents: Interactive Simulacra of Human Behavior [Park et al., 2023]
24
Link LLM & Agents
LLM as agents
• aim to create a high level of
interaction
• combination of several specilized LLM
• chain of LLM
• available tools:
LangChain, BabyAGI, and AutoGPT...
25
LLM as agents
• aim to create a high level of
interaction
• combination of several specilized LLM
• chain of LLM
• available tools:
LangChain, BabyAGI, and AutoGPT...

 why not computer–computer interaction?
25
LLM as agents
Retrieval Augmented Generation
• Question-Answering (QA)
• augmented search engine
26
What’s next?
Imagine future • In 2045, let’s imagine a future where
coding is obsolete and replaced by a
combination of agents...
[Ferber, 1999]
• The future is now: ◦ one can create and code a web
application from scratch using LLM
◦ computer scientist behaviors has
changed
◦ no need to be an expert to use LLMs ◦ one can assemble LLM as child
assemble lego bricks
27
Conclusion
Conclusion
• Even if it’s easier, research questions still open
28
Conclusion
• Even if it’s easier, research questions still open
• LLMs are not allways better than “classical” models
28
Conclusion
• Even if it’s easier, research questions still open
• LLMs are not allways better than “classical” models
• LLMs require huge amount of computationnal resources
28
Conclusion
• Even if it’s easier, research questions still open
• LLMs are not allways better than “classical” models
• LLMs require huge amount of computationnal resources
• LLMs require huge amount of data
28
Conclusion
• Even if it’s easier, research questions still open
• LLMs are not allways better than “classical” models
• LLMs require huge amount of computationnal resources
• LLMs require huge amount of data

 Design of specialized models
28
Conclusion
• Even if it’s easier, research questions still open
• LLMs are not allways better than “classical” models
• LLMs require huge amount of computationnal resources
• LLMs require huge amount of data

 Design of specialized models

 Models adapted to environment
28
Conclusion
• Even if it’s easier, research questions still open
• LLMs are not allways better than “classical” models
• LLMs require huge amount of computationnal resources
• LLMs require huge amount of data

 Design of specialized models

 Models adapted to environment

 Mix of Small (Language) Models and LLMs in Multi-Agent System
28
The end
Many thanks for your attention!
christophe.servan@lisn.upsaclay.fr
29
References i
Devlin, J., Chang, M.-W., Lee, K., and Toutanova, K. (2019).
BERT: Pre-training of deep bidirectional transformers for language understanding.
In Burstein, J., Doran, C., and Solorio, T., editors, Proceedings of the 2019
Conference of the North American Chapter of the Association for Computational
Linguistics: Human Language Technologies, Volume 1 (Long and Short Papers),
pages 4171–4186, Minneapolis, Minnesota. Association for Computational
Linguistics.
Ferber, J. (1999).
Multi-agent systems: an introduction to distributed artificial intelligence.
Addison Wesley Longman.
1
References ii
Franklin, S. and Graesser, A. (1996).
Is it an agent, or just a program?: A taxonomy for autonomous agents.
In International workshop on agent theories, architectures, and languages, pages
21–35. Springer.
Koehn, P., Och, F. J., and Marcu, D. (2003).
Statistical phrased-based machine translation.
In Joint Conference on Human Language Technology and of the North American
Chapter of the Association for Conputationnal Linguistics, pages 127–133.
Park, J. S., O’Brien, J., Cai, C. J., Morris, M. R., Liang, P., and Bernstein, M. S.
(2023).
Generative agents: Interactive simulacra of human behavior.
In Proceedings of the 36th Annual ACM Symposium on User Interface Software
and Technology, pages 1–22.
2
References iii
Povey, D., Ghoshal, A., Boulianne, G., Burget, L., Glembek, O., Goel, N.,
Hannemann, M., Motlicek, P., Qian, Y., Schwarz, P., et al. (2011).
The kaldi speech recognition toolkit.
In IEEE 2011 workshop on automatic speech recognition and understanding,
number CONF. IEEE Signal Processing Society.
Russell, S. J. and Norvig, P. (2003).
Probabilistic reasoning.
Artificial intelligence: a modern approach.
Servan, C., Raymond, C., B´echet, F., and Noc´era, P. (2006).
Conceptual decoding from word lattices: application to the spoken coprus media.
In INTERSPEECH - ICSLP, page 4, Pittsburgh, Pennsylvanie, Etats Unis ´
d’Am´erique.
3
References iv
Shoeybi, M., Patwary, M., Puri, R., LeGresley, P., Casper, J., and Catanzaro, B.
(2019).
Megatron-lm: Training multi-billion parameter language models using model
parallelism.
arXiv preprint arXiv:1909.08053.
Vaswani, A., Shazeer, N., Parmar, N., Uszkoreit, J., Jones, L., Gomez, A. N.,
Kaiser, L., and Polosukhin, I. (2017).
Attention is all you need.
Advances in neural information processing systems, 30.
Wooldridge, M. (2009).
An introduction to multiagent systems.
John wiley & sons.
4""")

confs.append("""
🎓 1. Parcours académique et thèse
Prépa → École (X) → Master TAL (Orsay) → Thèse au LIMSI (LISN).
Thèse "fondamentale appliquée" :
Transfert d’analyse en dépendance entre langues romanes.
Que faire avec très peu de données annotées ? (10-30 phrases seulement).
Exploration d’espace de recherche : test de séquences d’actions (mécanisme inspiré de l’apprentissage par renforcement et l’imitation learning).
Oracles dynamiques pour guider l’apprentissage.
Conclusions de sa recherche :
Mieux vaut un peu de données dans une langue cible qu'un gros dataset dans d'autres langues proches.
Ne pas réapprendre ce que l'on sait déjà (ex : ordre adjectif-nom en anglais → peut être intégré par des règles).
Complémentarité des sources : exploiter ce qui a été appris dans une langue pour en améliorer une autre.
Importance de prendre du recul pour voir les synergies possibles entre méthodes.
Conseils pour la thèse :
Enseigner n’est pas obligatoire (prend du temps).
Le domaine évolue vite, rester à jour.
Interagir avec d'autres chercheurs (réseau, machine à café, visiter d’autres labos).
La recherche peut être frustrante (manque de ressources, dépendance aux financements, résultats aléatoires).

🏛️ 2. Expérience en défense et industrie
2018 - 2021 : Chargée d’expertise en armement (DGA)
Poste très différent de la recherche.


Travail sur des contrats d’armement :


Codification stricte (marchés publics, concurrence).
Rédaction de spécifications techniques et suivi de projet.
Qualification et tests des outils.
Large diversité des cas d’usage :


TAL appliqué à des systèmes embarqués (avions, chars, bureautique, réseaux sociaux...).
Synthèse vocale, résumé automatique, extraction d’infos, détection de langues/dialectes.
Environnement complexe :


Mélange juridique et technique.
Organisation matricielle (plusieurs chefs de projet en parallèle).
Travail sur l’IA de confiance et l’éthique
Adapter les standards IA aux marchés publics.
Groupe pluridisciplinaire → création d’un guide méthodologique.
Participation aux discussions sur l’éthique de l’IA (Rapport Villani, recommandations européennes).
Vulgarisation pour des publics non-techniques.

🔬 3. Recherche appliquée et collaborations industrielles (INRIA)
2021 - 2023 : Recherche défense & sécurité
Faciliter le lien entre armées et chercheurs :


Traduire les besoins des militaires en problèmes de recherche.
Expliquer aux chercheurs les contraintes opérationnelles.
Travail en mode start-up :


Chercheuse, chef de projet, dev web, formatrice, juriste, recruteuse....
Dépôt de projets collaboratifs européens/nationaux (apprentissage du financement et de la gestion de projet).
Partenariats industriels :
Extraction informations pour la chimie.
IA pour l’aéronautique.
Conflits d’intérêts potentiels entre secteurs.
Développement de son propre projet de recherche :


Extraction information avec double enjeu : défense et méthodologie IA.

⚖️ 4. 2024 : IA et réglementation en Europe
Standardisation et réglementation IA
Travail sur les standards et normes IA.


Coordination de la feuille de route INRIA sur la standardisation.


Les standards aident à interpréter les lois (ex : AI Act) :


Norme harmonisée = présomption de conformité.
Organismes de normalisation :


AFNOR CN IA.
JTC 1 / SC 42 (ISO) & JTC 21.
Problème clé : faire dialoguer linguistes et data scientists (vision souvent opposée).



💡 5. Conseils et conclusions
Saisir les opportunités : un plan de carrière évolue constamment.
Réseau essentiel : le domaine de l’IA/TAL est un petit monde.
Utiliser sa science en dehors du monde académique : IA appliquée à la défense, l’industrie, la régulation.
Faire de la vulgarisation et de la communication : IA et TAL doivent être compris par des publics variés.

🎯 Conclusion
Lauriane Aufrant a un parcours varié, oscillant entre recherche fondamentale, défense, industrie et réglementation. Son expérience montre :
L’importance du TAL dans la défense et l’industrie.
L’essor des standards IA et leur rôle clé dans la régulation.
Les défis des projets collaboratifs et du financement en IA.
L’évolution des carrières en IA/TAL vers des domaines stratégiques (défense, réglementation, industrie).
Son message final : suivre les opportunités et adapter ses compétences à des contextes non académiques. 🚀
""")

# %%
#!spacy download fr_core_news_sm

# %%
import re
import spacy
import collections
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS

nlp = spacy.load("fr_core_news_sm")
stopwords_fr = nlp.Defaults.stop_words.union(STOPWORDS)

def preprocess_text(text):
    """ Nettoie et tokenize le texte en enlevant les stopwords et en lemmatisant les mots """
    text = re.sub(r"\b(d'|l')([a-zA-ZÀ-ÿ]+)", r"\2", text)
    doc = nlp(text)
    tokens = [token.lemma_.lower() for token in doc if token.lemma_ not in stopwords_fr and token.is_alpha]
    return tokens

def process_text(conference_text):
    """ Traite un texte de conférence et renvoie un DataFrame des mots les plus fréquents """
    words = preprocess_text(conference_text)
    word_counts = collections.Counter(words)
    df = pd.DataFrame(word_counts.items(), columns=["Word", "Frequency"]).sort_values(by="Frequency", ascending=False)
    return df

for i, conf in enumerate(confs):
    word_frequencies = process_text(conf)
    display(word_frequencies.head(10))
    plt.figure(figsize=(12, 6))
    plt.bar(word_frequencies["Word"][:10], word_frequencies["Frequency"][:10], color="hotpink")
    plt.xticks(rotation=45)
    plt.show()
# Out:
#            Word  Frequency
# 1        orange         10
# 20           ia         10
# 3           nlp          9
# 25    recherche          7
# 57       modèle          6
# 148         rag          5
# 133        fine          4
# 81        agent          4
# 87   évaluation          4
# 134      tuning          4
#              Word  Frequency
# 94             ia          9
# 7             tal          8
# 115       interne          5
# 92         projet          4
# 113  documentaire          4
# 49        analyse          4
# 114   information          4
# 81           sncf          4
# 14           eslo          4
# 88      recherche          4
#            Word  Frequency
# 1        thales        101
# 13       modèle         62
# 8      research         56
# 10       france         55
# 9    technology         53
# 11         trtp         50
# 12      version         50
# 387    relation         44
# 22   extraction         41
# 0           nlp         37
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import collections

top10 = ["recherche", "ia", "projet", "nlp", "modèle", "tal", "donnée", "information", "extraction", "relation"]

word_matrix = {}

for i, conf in enumerate(confs):
    word_frequencies = process_text(conf)
    word_counts = dict(zip(word_frequencies["Word"], word_frequencies["Frequency"]))
    word_matrix[f"Conf{i+1}"] = [word_counts.get(word, 0) for word in top10]

df_matrix = pd.DataFrame(word_matrix, index=top10)

colors = ["#ffb3e6", "#ff69b4", "#ff1493", "#c71585", "#9932cc", "#800080"]

plt.figure(figsize=(12, 6))
x = np.arange(len(top10))
width = 0.13

for i, (conf, freq) in enumerate(df_matrix.items()):
    plt.bar(x + (i - (len(df_matrix.columns) / 2)) * width, freq, width=width,
            label=conf, color=colors[i % len(colors)])

plt.xticks(x, top10, rotation=45)
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
sns.heatmap(df_matrix, annot=True, cmap="PiYG", fmt=".0f", linewidths=0.5)
plt.show()
